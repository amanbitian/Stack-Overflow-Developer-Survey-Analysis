# %% [markdown]
# # Stack Overflow Developer Survey, 2020
# Heads up!
# * Survey tends to have some biasness as all programmers don't use stackover flow, so dataset may represent like minded people
# * Survey dataset in general tends to have a lot of **human error** which must be looked for.
# > a. Respondents may not feel encouraged to provide accurate, honest answers
# b. Respondents may not be fully aware of their reasons for any given answer because of lack of memory on the subject, or even boredom.
# c. Surveys with closed-ended questions may have a lower validity rate than other question types.
# d. Data errors due to question non-responses may exist. which leads to `NaN` Values
# e. The number of respondents who choose to respond to a survey question may be different from those who chose not to respond, thus creating bias.
#
# ## `Errors in Survey dataset`
# 1. **Survey error** refers to `mistakes made in the construction and implementation of the survey instrument, as well as the interpretation of results.` Survey error is associated with `completeness, interpretability of the data, and the generalizability of the results.` *This type of error affects the validity of the measurement and what is called* ***measurement error***. Survey error is avoided, to some extent, by carefully designing the study, creating a comprehensive set of well-crafted survey items, and properly interpreting and presenting the results.
# 2. **Purpose Creep Error** At times researchers (or clients) will add items to a survey that don’t directly align with the needs and purposes of the study.
# 3. **Sampling Error** This occurs when mistakes are made selecting a sample. Sampling error typically occurs when a specific subgroup within the population is under- or overrepresented in the sample. When this happens, the results obtained from the survey are not generalizable. This is because the characteristics of respondents in the sample do not match proportionally with the characteristics of those in the population. This can easily happen with small samples, especially when there are a number of small subgroups within the population.
# 4. **Item Nonresponse Error** This happens when a participant fails to answer all the questions on a survey. It can happen by accident or intentionally. Nonresponse is unfortunate when you are administering a questionnaire but does not necessarily invalidate the results; the results depend on how many respondents failed to answer a specific question.
#
# ## `Common Forms of Response Bias`
# 1. **Response bias** is a general term that describes the ways a respondent may be influenced when self-reporting their answers on a survey. Bias affects the accuracy and reliability of the results. There are several ways in which an individual’s response may be inaccurate. The inaccuracy, or bias, may be deliberate or subconscious on the part of the respondent; it is the result of a respondent being unduly influenced to respond in a certain way, or a respondent’s unwillingness to answer the questions honestly. Bias can be caused when items are unclear or poorly constructed but can also occur as a result of the response scale selected for participants to use when they provide their answers. Never underestimate the propensity of individuals to misunderstand what is being asked or otherwise provide information that is inaccurate to some degree.
# 2. **Random Response Bias** Random response bias can occur when a respondent honestly does not know the answer to the question but answers anyway.
# 3. **Demand Characteristic Bias** A demand characteristic is used to describe specific cues in research that may inadvertently influence a participant’s response.
# 4. **Central Tendency Bias** This bias refers to the tendency of some individuals to avoid responding in extreme ways.
# 5. **Mood Bias and Emotional Mind Sets** One’s mood or mindset will affect the way responses are provided.
# 6. **Item and Option Order Effect Bias** Order bias can be the result of both item order and response option order. The order in which survey items are presented can affect a respondent’s answers due to a priming effect. People tend to contextualize their responses. Because of this, survey questions that come just before a particular query may provide information that respondents will use as context in formulating their subsequent answers. If a different primer was presented, the responses may be significantly different.
# `Two common response biases associated with response option order` are **primacy and recency bias**.**Primacy bias** is the tendency for respondents to pick one of the first options presented to them. This can happen when a respondent quickly reads through the survey and picks one of the first response options they agree with.**Recency bias** is the tendency to pick an answer option presented at the end of a list. For example, in a long list of options, the choices respondents read last are more memorable to the respondent as they select an answer.
# 7. **Prestige Bias** This bias is related to social desirability bias as it is based on an individual’s personal desire to be seen in a positive light. This bias is based on personal feelings, not a general instinct for conformity.
# 8. **Acquiescence or Agreement Bias** This bias is like conformity bias. However, unlike conformity bias, in this case the respondent will, in general and inadvertently, agree with statements. With this bias, participants tend to select a positive response option or disproportionately indicate a positive connotation. `This bias will skew results towards the positive.`

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)
import warnings
warnings.filterwarnings('ignore')

# %%
schema= pd.read_csv('../input/stack-overflow-developer-survey-2020/survey_results_schema.csv', index_col='Column') ## setting column name as index so that we can easily access question
df=pd.read_csv('../input/stack-overflow-developer-survey-2020/survey_results_public.csv')
print('Questions asked in survey','\n')
display(schema.head(60))
print()
df
# Out:
# Questions asked in survey
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Sexuality                     Which of the following describe you, if any? P...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc CurrencySymbol  \
# 0       European Euro            EUR
# 1      Pound sterling            GBP
# 2                 NaN            NaN
# 3        Albanian lek            ALL
# 4                 NaN            NaN
# ...               ...            ...
# 64456             NaN            NaN
# 64457             NaN            NaN
# 64458             NaN            NaN
# 64459             NaN            NaN
# 64460             NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 0                                   Microsoft SQL Server
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                       MySQL;PostgreSQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459    DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 64460                       MariaDB;Microsoft SQL Server
#
#                                       DatabaseWorkedWith  \
# 0              Elasticsearch;Microsoft SQL Server;Oracle
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                          MySQL;PostgreSQL;Redis;SQLite
# ...                                                  ...
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459                                             Oracle
# 64460          MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                  DevType  \
# 0      Developer, desktop or enterprise applications;...
# 1                Developer, full-stack;Developer, mobile
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64456                                Senior executive/VP
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                           Ethnicity Gender  \
# 0      White or of European descent    Man
# 1                               NaN    NaN
# 2                               NaN    NaN
# 3      White or of European descent    Man
# 4      White or of European descent    Man
# ...                             ...    ...
# 64456                           NaN    NaN
# 64457                           NaN    NaN
# 64458                           NaN    NaN
# 64459                           NaN    NaN
# 64460                           NaN    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                                  JobSeek  \
# 0           I am not interested in new job opportunities
# 1           I am not interested in new job opportunities
# 2                                                    NaN
# 3      I’m not actively looking, but I am open to new...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                   LanguageDesireNextYear  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                           Python;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                        Java;Ruby;Scala
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                           HTML/CSS;Java;JavaScript
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                  MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                     .NET Core;Xamarin     .NET;.NET Core
# 1      React Native;TensorFlow;Unity 3D       React Native
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                          Ansible;Chef            Ansible
# ...                                 ...                ...
# 64456                               NaN                NaN
# 64457                               NaN                NaN
# 64458                               NaN                NaN
# 64459                           Node.js                NaN
# 64460                 .NET Core;Xamarin     .NET;.NET Core
#
#                  NEWCollabToolsDesireNextYear  \
# 0      Microsoft Teams;Microsoft Azure;Trello
# 1                                Github;Slack
# 2                                         NaN
# 3                                         NaN
# 4       Github;Google Suite (Docs, Meet, etc)
# ...                                       ...
# 64456                                     NaN
# 64457                                     NaN
# 64458                                     NaN
# 64459                           Github;Gitlab
# 64460                  Github;Microsoft Teams
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 0           Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                    Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN        No
# 4      Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                  ...       ...
# 64456                                                NaN       NaN
# 64457                                                NaN       NaN
# 64458                                                NaN       NaN
# 64459              Confluence;Jira;Slack;Microsoft Teams       NaN
# 64460                                             Github       NaN
#
#             NEWDevOpsImpt                           NEWEdImpt  \
# 0      Somewhat important                    Fairly important
# 1                     NaN                    Fairly important
# 2                     NaN                                 NaN
# 3                     NaN  Not at all important/not necessary
# 4                     NaN                      Very important
# ...                   ...                                 ...
# 64456                 NaN                      Very important
# 64457                 NaN                                 NaN
# 64458                 NaN                                 NaN
# 64459                 NaN                                 NaN
# 64460                 NaN                Critically important
#
#                                               NEWJobHunt NEWJobHuntResearch  \
# 0                                                    NaN                NaN
# 1                                                    NaN                NaN
# 2                                                    NaN                NaN
# 3      Curious about other opportunities;Wanting to w...                NaN
# 4                                                    NaN                NaN
# ...                                                  ...                ...
# 64456                                                NaN                NaN
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                                NaN                NaN
# 64460                                                NaN                NaN
#
#             NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0        Once a year    Not sure            NaN            No
# 1        Once a year    Not sure            NaN            No
# 2      Once a decade         NaN            NaN            No
# 3        Once a year    Not sure            Yes           Yes
# 4        Once a year          No            NaN           Yes
# ...              ...         ...            ...           ...
# 64456  Once a decade         NaN            NaN           NaN
# 64457            NaN         NaN            NaN           NaN
# 64458            NaN         NaN            NaN           NaN
# 64459    Once a year         NaN            NaN           NaN
# 64460    Once a year         NaN            NaN           NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 0      Start a free trial;Ask developers I know/work ...             Amused
# 1                                                    NaN             Amused
# 2                                                    NaN                NaN
# 3                                                    NaN                NaN
# 4      Start a free trial;Ask developers I know/work ...  Hello, old friend
# ...                                                  ...                ...
# 64456                                 Start a free trial             Amused
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                 Start a free trial  Hello, old friend
# 64460  Start a free trial;Ask developers I know/work ...        Indifferent
#
#                                               NEWSOSites  \
# 0       Stack Overflow (public Q&A for anyone who codes)
# 1      Stack Overflow (public Q&A for anyone who code...
# 2       Stack Overflow (public Q&A for anyone who codes)
# 3      Stack Overflow (public Q&A for anyone who code...
# 4      Stack Overflow (public Q&A for anyone who code...
# ...                                                  ...
# 64456   Stack Overflow (public Q&A for anyone who codes)
# 64457                                                NaN
# 64458                                                NaN
# 64459   Stack Overflow (public Q&A for anyone who codes)
# 64460                                                NaN
#
#                                                 NEWStuck        OpSys  \
# 0      Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1      Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                    NaN  Linux-based
# 3                                                    NaN  Linux-based
# 4      Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                  ...          ...
# 64456                          Call a coworker or friend      Windows
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459     Call a coworker or friend;Visit Stack Overflow      Windows
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                         OrgSize  \
# 0              2 to 9 employees
# 1      1,000 to 4,999 employees
# 2                           NaN
# 3            20 to 99 employees
# 4                           NaN
# ...                         ...
# 64456                       NaN
# 64457                       NaN
# 64458                       NaN
# 64459                       NaN
# 64460                       NaN
#
#                                   PlatformDesireNextYear  \
# 0         Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                             iOS;Kubernetes;Linux;MacOS
# 2                                                    NaN
# 3                                                    NaN
# 4      Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                 Arduino;Linux;Raspberry Pi;Windows
#
#                                PlatformWorkedWith  \
# 0                                         Windows
# 1                                             iOS
# 2                                             NaN
# 3                                             NaN
# 4                  AWS;Docker;Linux;MacOS;Windows
# ...                                           ...
# 64456                                         NaN
# 64457                                         NaN
# 64458                                         NaN
# 64459                               Linux;Windows
# 64460  Android;Arduino;Linux;Raspberry Pi;Windows
#
#                            PurchaseWhat                Sexuality SOAccount  \
# 0                                   NaN  Straight / Heterosexual        No
# 1         I have little or no influence                      NaN       Yes
# 2                                   NaN                      NaN       Yes
# 3      I have a great deal of influence  Straight / Heterosexual       Yes
# 4                                   NaN  Straight / Heterosexual       Yes
# ...                                 ...                      ...       ...
# 64456                               NaN                      NaN       NaN
# 64457                               NaN                      NaN       NaN
# 64458                               NaN                      NaN       NaN
# 64459                               NaN                      NaN       NaN
# 64460                               NaN                      NaN       NaN
#
#                 SOComm                           SOPartFreq  \
# 0       No, not at all                                  NaN
# 1      Yes, definitely  Less than once per month or monthly
# 2        Yes, somewhat      A few times per month or weekly
# 3      Yes, definitely      A few times per month or weekly
# 4        Yes, somewhat  Less than once per month or monthly
# ...                ...                                  ...
# 64456              NaN                                  NaN
# 64457              NaN                                  NaN
# 64458              NaN                                  NaN
# 64459              NaN                                  NaN
# 64460              NaN                                  NaN
#
#                            SOVisitFreq                  SurveyEase  \
# 0               Multiple times per day  Neither easy nor difficult
# 1               Multiple times per day                         NaN
# 2                Daily or almost daily  Neither easy nor difficult
# 3               Multiple times per day                         NaN
# 4      A few times per month or weekly                        Easy
# ...                                ...                         ...
# 64456                              NaN                         NaN
# 64457                              NaN                         NaN
# 64458                              NaN                         NaN
# 64459                              NaN                         NaN
# 64460                              NaN                         NaN
#
#                 SurveyLength Trans  \
# 0      Appropriate in length    No
# 1                        NaN   NaN
# 2      Appropriate in length   NaN
# 3                        NaN    No
# 4                  Too short    No
# ...                      ...   ...
# 64456                    NaN   NaN
# 64457                    NaN   NaN
# 64458                    NaN   NaN
# 64459                    NaN   NaN
# 64460                    NaN   NaN
#
#                                           UndergradMajor  \
# 0      Computer science, computer engineering, or sof...
# 1      Computer science, computer engineering, or sof...
# 2                                                    NaN
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange  WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year         50.0        36
# 1      Somewhat more welcome now than last year          NaN         7
# 2      Somewhat more welcome now than last year          NaN         4
# 3      Somewhat less welcome now than last year         40.0         7
# 4       Just as welcome now as I felt last year          NaN        15
# ...                                         ...          ...       ...
# 64456                                       NaN          NaN        10
# 64457                                       NaN          NaN       NaN
# 64458                                       NaN          NaN       NaN
# 64459                                       NaN          NaN       NaN
# 64460                                       NaN          NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
categoricat_feature= df.select_dtypes(include='object').columns
categoricat_feature
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age1stCode', 'CompFreq', 'Country',
#        'CurrencyDesc', 'CurrencySymbol', 'DatabaseDesireNextYear',
#        'DatabaseWorkedWith', 'DevType', 'EdLevel', 'Employment', 'Ethnicity',
#        'Gender', 'JobFactors', 'JobSat', 'JobSeek', 'LanguageDesireNextYear',
#        'LanguageWorkedWith', 'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'YearsCode', 'YearsCodePro'],
#       dtype='object')

# %%
non_obj_feature= df.select_dtypes(exclude='object').columns
non_obj_feature
# Out:
# Index(['Respondent', 'Age', 'CompTotal', 'ConvertedComp', 'WorkWeekHrs'], dtype='object')

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df.isnull());

# %% [markdown]
# There are a lot of missing data

# %%
(df.isnull().mean()*100).sort_values(ascending=False).head(45)
# Out:
# ConvertedComp                   46.082127
# CompTotal                       45.973534
# NEWPurchaseResearch             42.102977
# PurchaseWhat                    38.933619
# WebframeDesireNextYear          37.909744
# CompFreq                        37.839934
# MiscTechWorkedWith              37.459859
# NEWJobHuntResearch              36.361521
# WorkWeekHrs                     36.161400
# NEWDevOpsImpt                   35.260080
# WebframeWorkedWith              34.411505
# NEWJobHunt                      34.400645
# MiscTechDesireNextYear          34.256372
# NEWOnboardGood                  33.877849
# NEWDevOps                       33.780115
# NEWOvertime                     32.934643
# Sexuality                       31.754084
# DatabaseDesireNextYear          31.633080
# OrgSize                         31.223531
# JobSat                          29.889390
# Age                             29.498456
# CurrencySymbol                  29.458122
# CurrencyDesc                    29.458122
# Ethnicity                       28.719691
# YearsCodePro                    28.097609
# SOPartFreq                      27.410372
# NEWCollabToolsDesireNextYear    26.642466
# NEWEdImpt                       24.815004
# Trans                           23.449838
# JobFactors                      23.443633
# DevType                         23.411055
# DatabaseWorkedWith              23.151983
# Gender                          21.569631
# PlatformDesireNextYear          21.495168
# NEWOffTopic                     21.186454
# UndergradMajor                  20.890151
# SurveyLength                    19.794915
# JobSeek                         19.754580
# SurveyEase                      19.638231
# WelcomeChange                   18.271513
# NEWCollabToolsWorkedWith        17.961248
# PlatformWorkedWith              16.471975
# LanguageDesireNextYear          16.053117
# NEWPurpleLink                   14.982703
# NEWStuck                        14.703464
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
#  12  DatabaseWorkedWith            49537 non-null  object
#  13  DevType                       49370 non-null  object
#  14  EdLevel                       57431 non-null  object
#  15  Employment                    63854 non-null  object
#  16  Ethnicity                     45948 non-null  object
#  17  Gender                        50557 non-null  object
#  18  JobFactors                    49349 non-null  object
#  19  JobSat                        45194 non-null  object
#  20  JobSeek                       51727 non-null  object
#  21  LanguageDesireNextYear        54113 non-null  object
#  22  LanguageWorkedWith            57378 non-null  object
#  23  MiscTechDesireNextYear        42379 non-null  object
#  24  MiscTechWorkedWith            40314 non-null  object
#  25  NEWCollabToolsDesireNextYear  47287 non-null  object
#  26  NEWCollabToolsWorkedWith      52883 non-null  object
#  27  NEWDevOps                     42686 non-null  object
#  28  NEWDevOpsImpt                 41732 non-null  object
#  29  NEWEdImpt                     48465 non-null  object
#  30  NEWJobHunt                    42286 non-null  object
#  31  NEWJobHuntResearch            41022 non-null  object
#  32  NEWLearn                      56156 non-null  object
#  33  NEWOffTopic                   50804 non-null  object
#  34  NEWOnboardGood                42623 non-null  object
#  35  NEWOtherComms                 57205 non-null  object
#  36  NEWOvertime                   43231 non-null  object
#  37  NEWPurchaseResearch           37321 non-null  object
#  38  NEWPurpleLink                 54803 non-null  object
#  39  NEWSOSites                    58275 non-null  object
#  40  NEWStuck                      54983 non-null  object
#  41  OpSys                         56228 non-null  object
#  42  OrgSize                       44334 non-null  object
#  43  PlatformDesireNextYear        50605 non-null  object
#  44  PlatformWorkedWith            53843 non-null  object
#  45  PurchaseWhat                  39364 non-null  object
#  46  Sexuality                     43992 non-null  object
#  47  SOAccount                     56805 non-null  object
#  48  SOComm                        56476 non-null  object
#  49  SOPartFreq                    46792 non-null  object
#  50  SOVisitFreq                   56970 non-null  object
#  51  SurveyEase                    51802 non-null  object
#  52  SurveyLength                  51701 non-null  object
#  53  Trans                         49345 non-null  object
#  54  UndergradMajor                50995 non-null  object
#  55  WebframeDesireNextYear        40024 non-null  object
#  56  WebframeWorkedWith            42279 non-null  object
#  57  WelcomeChange                 52683 non-null  object
#  58  WorkWeekHrs                   41151 non-null  float64
#  59  YearsCode                     57684 non-null  object
#  60  YearsCodePro                  46349 non-null  object
# dtypes: float64(4), int64(1), object(56)
# memory usage: 30.0+ MB

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %% [markdown]
# There are few outliers/strange data feeded
# 1. Age min is `1 year` and max is `279 years`
# 2. Working hour/ week min is `1hr` which to me seem false, and max is `475hr/week` which is again **not possible as 24*7=168**
# 3. Why does **CompTotal** have std infinite?

# %%
### Extracting questions from schema
print(schema.loc['CompTotal'])
# Out:
# QuestionText    What is your current total compensation (salar...
# Name: CompTotal, dtype: object

# %% [markdown]
# This is printing half question so to solve this issue I will convert this df into series
# As this df only have 1 column and `Column` is set as index this won't be bothering
# Lets check it

# %%
schema_df = schema.QuestionText
schema_df.loc['CompTotal']
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in `CurrencySymbol`? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %% [markdown]
# This question explicitly ask people to input `whole no` it seems people didn't follow through

# %% [markdown]
# ## Data Preparation & Cleaning
#
# While the survey responses contain a wealth of information, we'll limit our analysis to the following areas:
#
# - Demographics of the survey respondents and the global programming community
# - Distribution of programming skills, experience, and preferences
# - Employment-related information, preferences, and opinions
#
# Let's select a subset of columns with the relevant data for our analysis.

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
len(selected_columns)
# Out:
# 20

# %%
# Let's extract a copy of the data from these columns into a new data frame `survey_df`.
## We can continue to modify further without affecting the original data frame.
sdf = df[selected_columns].copy()
display(sdf.sample(10))

## Same for schema

schema = schema_df[selected_columns]
display(schema.head(5))
# Out:
#              Country   Age Gender  \
# 52284  United States  42.0  Woman
# 56901    Netherlands  25.0    Man
# 31941        Germany  28.0    Man
# 54904          India   NaN    NaN
# 19376        Germany  34.0    Man
# 37398          India   NaN    NaN
# 20789     Bangladesh  30.0    Man
# 264    United States  69.0    Man
# 6433      Bangladesh  30.0    Man
# 44422  United States  28.0  Woman
#
#                                                  EdLevel  \
# 52284  Some college/university study without earning ...
# 56901       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 31941  Some college/university study without earning ...
# 54904                                                NaN
# 19376  Secondary school (e.g. American high school, G...
# 37398  Secondary school (e.g. American high school, G...
# 20789    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 264                  Associate degree (A.A., A.S., etc.)
# 6433        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44422       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           UndergradMajor Hobbyist Age1stCode  \
# 52284                      Web development or web design      Yes         35
# 56901  Computer science, computer engineering, or sof...       No         16
# 31941  Computer science, computer engineering, or sof...      Yes         13
# 54904                                                NaN      Yes        NaN
# 19376                                                NaN      Yes         14
# 37398                                                NaN      Yes         16
# 20789  Computer science, computer engineering, or sof...      Yes         19
# 264    Computer science, computer engineering, or sof...      Yes         25
# 6433   Computer science, computer engineering, or sof...      Yes         21
# 44422  Computer science, computer engineering, or sof...       No         10
#
#       YearsCode YearsCodePro  \
# 52284         2          NaN
# 56901         8          NaN
# 31941        15            5
# 54904       NaN          NaN
# 19376        16           12
# 37398         4          NaN
# 20789        10            5
# 264          40          NaN
# 6433         10            6
# 44422        10            6
#
#                                       LanguageWorkedWith  \
# 52284                                HTML/CSS;JavaScript
# 56901               C#;HTML/CSS;Java;JavaScript;Ruby;SQL
# 31941                                C#;C++;HTML/CSS;SQL
# 54904                                                NaN
# 19376  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 37398                     C;C++;HTML/CSS;Java;JavaScript
# 20789                                        C#;C++;Java
# 264    Bash/Shell/PowerShell;C#;JavaScript;Kotlin;SQL...
# 6433                                         Java;Kotlin
# 44422        Bash/Shell/PowerShell;Python;SQL;TypeScript
#
#                                   LanguageDesireNextYear  \
# 52284                     HTML/CSS;JavaScript;TypeScript
# 56901                       HTML/CSS;JavaScript;Ruby;SQL
# 31941                                    C#;C++;HTML/CSS
# 54904                                                NaN
# 19376  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 37398                             Java;JavaScript;Python
# 20789                                        Java;Python
# 264    Bash/Shell/PowerShell;JavaScript;Kotlin;Ruby;S...
# 6433                               C++;Java;Kotlin;Swift
# 44422                    Bash/Shell/PowerShell;Go;Python
#
#                    NEWLearn  \
# 52284           Once a year
# 56901  Once every few years
# 31941                   NaN
# 54904                   NaN
# 19376           Once a year
# 37398           Once a year
# 20789           Once a year
# 264        Every few months
# 6433            Once a year
# 44422           Once a year
#
#                                                 NEWStuck  \
# 52284  Visit Stack Overflow;Go for a walk or other ph...
# 56901  Call a coworker or friend;Visit Stack Overflow...
# 31941  Call a coworker or friend;Visit Stack Overflow...
# 54904                                                NaN
# 19376  Call a coworker or friend;Visit Stack Overflow...
# 37398  Call a coworker or friend;Visit Stack Overflow...
# 20789  Play games;Call a coworker or friend;Visit Sta...
# 264    Visit Stack Overflow;Watch help / tutorial vid...
# 6433      Call a coworker or friend;Visit Stack Overflow
# 44422  Play games;Call a coworker or friend;Visit Sta...
#
#                                               Employment  \
# 52284                                 Employed full-time
# 56901                                            Student
# 31941                                 Employed full-time
# 54904                                            Student
# 19376  Independent contractor, freelancer, or self-em...
# 37398                                            Student
# 20789                                 Employed full-time
# 264                                              Retired
# 6433                                  Employed full-time
# 44422                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 52284                               Developer, front-end          NaN
# 56901                                                NaN          NaN
# 31941  Developer, desktop or enterprise applications;...         35.0
# 54904                                                NaN          NaN
# 19376  Developer, full-stack;Developer, game or graph...         60.0
# 37398                                                NaN          NaN
# 20789  Academic researcher;Data scientist or machine ...          NaN
# 264                                                  NaN          NaN
# 6433                                   Developer, mobile         56.0
# 44422                                Developer, back-end         40.0
#
#                    JobSat                                         JobFactors  \
# 52284                 NaN  Languages, frameworks, and other technologies ...
# 56901                 NaN  Diversity of the company or organization;Flex ...
# 31941  Slightly satisfied  Flex time or a flexible schedule;Office enviro...
# 54904                 NaN                                                NaN
# 19376      Very satisfied  Languages, frameworks, and other technologies ...
# 37398                 NaN  Flex time or a flexible schedule;Specific depa...
# 20789                 NaN                                                NaN
# 264                   NaN                                                NaN
# 6433   Slightly satisfied  Industry that I’d be working in;Office environ...
# 44422      Very satisfied  Flex time or a flexible schedule;How widely us...
#
#                                              NEWOvertime           NEWEdImpt
# 52284                                                NaN                 NaN
# 56901                                                NaN                 NaN
# 31941  Sometimes: 1-2 days per month but less than we...  Somewhat important
# 54904                                                NaN                 NaN
# 19376                   Often: 1-2 days per week or more  Somewhat important
# 37398                                                NaN                 NaN
# 20789                                                NaN      Very important
# 264                                                  NaN    Fairly important
# 6433                    Often: 1-2 days per week or more    Fairly important
# 44422                                              Never      Very important
# Column
# Country                                          Where do you live?
# Age               What is your age (in years)? If you prefer not...
# Gender            Which of the following describe you, if any? P...
# EdLevel           Which of the following best describes the high...
# UndergradMajor                What was your primary field of study?
# Name: QuestionText, dtype: object

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
#  14  DevType                 49370 non-null  object
#  15  WorkWeekHrs             41151 non-null  float64
#  16  JobSat                  45194 non-null  object
#  17  JobFactors              49349 non-null  object
#  18  NEWOvertime             43231 non-null  object
#  19  NEWEdImpt               48465 non-null  object
# dtypes: float64(2), object(18)
# memory usage: 9.8+ MB

# %% [markdown]
# **Age1stCode**, **YearsCode**,**YearsCodePro** seems to have float datatype but are stored as object
# Lets explore it's reason...

# %%
sdf['Age1stCode'].unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
sdf['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
sdf['YearsCodePro'].unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %% [markdown]
# It seems these columns store few object data type like :  "Less than 1 year",'More than 50 years' , 'Younger than 5 years' , 'Older than 85' etc
# we can solve this problem in 2 way
# 1. Use error management like, `errors='coerce'`
# > errors : {‘ignore’, ‘raise’, ‘coerce’}, default ‘raise’
#      If **‘raise’**, then invalid parsing will raise an exception
#      If **‘coerce’**, then invalid parsing will be set as NaN
#      If **‘ignore**’, then invalid parsing will return the input
#
# 2. Use some numerical values to idicate they belong to outliers

# %%
sdf[sdf['YearsCodePro']== 'More than 50 years']
# Out:
#               Country   Age  \
# 640     United States  71.0
# 717     United States  70.0
# 1099    United States   NaN
# 1564    United States  84.0
# 2625           Canada  99.0
# 3069    United States   NaN
# 3202    United States  73.0
# 5446           Canada  68.0
# 6964         Viet Nam   NaN
# 10710           India  70.0
# 11018          Israel  77.0
# 12064    South Africa  85.0
# 13619   United States  71.0
# 14033  United Kingdom  76.0
# 14348  United Kingdom  79.0
# 17911   United States  73.0
# 18246   United States   NaN
# 19706   United States  74.0
# 24722   United States  73.0
# 25796        Thailand   NaN
# 26962         Germany   NaN
# 27098          Greece  69.0
# 29732   United States  78.0
# 33617   United States  88.0
# 34551   United States  65.0
# 37797       Indonesia   NaN
# 39170         Andorra   NaN
# 41822         Myanmar   NaN
# 42328   United States   NaN
# 44735   United States   NaN
# 45732        Thailand   NaN
# 45753         Nomadic   NaN
# 46677   United States   NaN
# 50908   United States  81.0
# 52363   United States   NaN
# 52768   United States  83.0
# 52950          Canada  69.0
# 56507     Afghanistan   NaN
# 62890         Finland   NaN
# 63793        Viet Nam   NaN
# 63993     Afghanistan   NaN
# 64288       Australia   NaN
#
#                                                   Gender  \
# 640                                                  Man
# 717                                                  Man
# 1099                                                 Man
# 1564                                                 Man
# 2625   Woman;Man;Non-binary, genderqueer, or gender n...
# 3069                                                 Man
# 3202                                                 Man
# 5446                                                 Man
# 6964   Woman;Man;Non-binary, genderqueer, or gender n...
# 10710                                                Man
# 11018                                                Man
# 12064                                                Man
# 13619                                                Man
# 14033                                                Man
# 14348                                                Man
# 17911                                                Man
# 18246                                              Woman
# 19706                                                Man
# 24722                                                Man
# 25796                                                NaN
# 26962                                                NaN
# 27098                                                Man
# 29732                                                Man
# 33617                                                Man
# 34551                                                Man
# 37797                                                NaN
# 39170                                                NaN
# 41822                                                NaN
# 42328                                                NaN
# 44735                                                Man
# 45732                                                NaN
# 45753                                                NaN
# 46677                                                Man
# 50908                                                Man
# 52363                                                Man
# 52768                                                Man
# 52950                                                Man
# 56507                                                NaN
# 62890                                                NaN
# 63793                                                NaN
# 63993                                                NaN
# 64288                                                NaN
#
#                                                  EdLevel  \
# 640                                                  NaN
# 717           Other doctoral degree (Ph.D., Ed.D., etc.)
# 1099          Other doctoral degree (Ph.D., Ed.D., etc.)
# 1564          Other doctoral degree (Ph.D., Ed.D., etc.)
# 2625        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3069          Other doctoral degree (Ph.D., Ed.D., etc.)
# 3202     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5446                  Professional degree (JD, MD, etc.)
# 6964   Some college/university study without earning ...
# 10710             I never completed any formal education
# 11018  Some college/university study without earning ...
# 12064         Other doctoral degree (Ph.D., Ed.D., etc.)
# 13619    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 14033    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 14348         Other doctoral degree (Ph.D., Ed.D., etc.)
# 17911    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18246       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19706       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24722    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 25796  Some college/university study without earning ...
# 26962                 Professional degree (JD, MD, etc.)
# 27098    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 29732       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33617    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34551  Some college/university study without earning ...
# 37797                                                NaN
# 39170                                                NaN
# 41822             I never completed any formal education
# 42328                                                NaN
# 44735  Some college/university study without earning ...
# 45732                                                NaN
# 45753                          Primary/elementary school
# 46677    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 50908    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 52363       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 52768       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 52950       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 56507             I never completed any formal education
# 62890       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63793  Some college/university study without earning ...
# 63993         Other doctoral degree (Ph.D., Ed.D., etc.)
# 64288    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           UndergradMajor Hobbyist  \
# 640                            Mathematics or statistics      Yes
# 717    A natural science (such as biology, chemistry,...      Yes
# 1099                                                 NaN      Yes
# 1564                                                 NaN      Yes
# 2625   Computer science, computer engineering, or sof...       No
# 3069   Another engineering discipline (such as civil,...       No
# 3202   Computer science, computer engineering, or sof...      Yes
# 5446   Information systems, information technology, o...      Yes
# 6964   Information systems, information technology, o...      Yes
# 10710                                                NaN       No
# 11018                          Mathematics or statistics      Yes
# 12064                          Mathematics or statistics       No
# 13619  Computer science, computer engineering, or sof...       No
# 14033                          Mathematics or statistics       No
# 14348  A natural science (such as biology, chemistry,...       No
# 17911                                                NaN      Yes
# 18246  A natural science (such as biology, chemistry,...       No
# 19706  Another engineering discipline (such as civil,...       No
# 24722  Computer science, computer engineering, or sof...       No
# 25796  Another engineering discipline (such as civil,...      Yes
# 26962  Computer science, computer engineering, or sof...      Yes
# 27098                          Mathematics or statistics       No
# 29732  A natural science (such as biology, chemistry,...       No
# 33617  A natural science (such as biology, chemistry,...      Yes
# 34551  Computer science, computer engineering, or sof...      Yes
# 37797                      Web development or web design      Yes
# 39170                                                NaN      Yes
# 41822                                                NaN      Yes
# 42328                                                NaN      Yes
# 44735  Information systems, information technology, o...       No
# 45732                                                NaN       No
# 45753                                                NaN      Yes
# 46677  A natural science (such as biology, chemistry,...      Yes
# 50908  Computer science, computer engineering, or sof...       No
# 52363                          Mathematics or statistics      Yes
# 52768                          Mathematics or statistics       No
# 52950  Computer science, computer engineering, or sof...       No
# 56507                                                NaN      Yes
# 62890                                                NaN      Yes
# 63793  Computer science, computer engineering, or sof...      Yes
# 63993  Information systems, information technology, o...      Yes
# 64288                           I never declared a major      Yes
#
#                  Age1stCode           YearsCode        YearsCodePro  \
# 640                      14  More than 50 years  More than 50 years
# 717                      16  More than 50 years  More than 50 years
# 1099                     18  More than 50 years  More than 50 years
# 1564                     20  More than 50 years  More than 50 years
# 2625          Older than 85  More than 50 years  More than 50 years
# 3069                     18  More than 50 years  More than 50 years
# 3202                     18  More than 50 years  More than 50 years
# 5446                     16  More than 50 years  More than 50 years
# 6964          Older than 85  More than 50 years  More than 50 years
# 10710                     6  More than 50 years  More than 50 years
# 11018                    17  More than 50 years  More than 50 years
# 12064                    28  More than 50 years  More than 50 years
# 13619                    19  More than 50 years  More than 50 years
# 14033                    18  More than 50 years  More than 50 years
# 14348                    21  More than 50 years  More than 50 years
# 17911                    21  More than 50 years  More than 50 years
# 18246                    19  More than 50 years  More than 50 years
# 19706                    18  More than 50 years  More than 50 years
# 24722                    24  More than 50 years  More than 50 years
# 25796         Older than 85  More than 50 years  More than 50 years
# 26962                    12  More than 50 years  More than 50 years
# 27098                    18  More than 50 years  More than 50 years
# 29732                    23  More than 50 years  More than 50 years
# 33617                    20  More than 50 years  More than 50 years
# 34551                    10  More than 50 years  More than 50 years
# 37797         Older than 85  More than 50 years  More than 50 years
# 39170         Older than 85  More than 50 years  More than 50 years
# 41822                    33  More than 50 years  More than 50 years
# 42328         Older than 85  More than 50 years  More than 50 years
# 44735                     7  More than 50 years  More than 50 years
# 45732         Older than 85  More than 50 years  More than 50 years
# 45753  Younger than 5 years  More than 50 years  More than 50 years
# 46677                    23  More than 50 years  More than 50 years
# 50908                    27  More than 50 years  More than 50 years
# 52363                    17  More than 50 years  More than 50 years
# 52768                    21  More than 50 years  More than 50 years
# 52950                    18  More than 50 years  More than 50 years
# 56507  Younger than 5 years  More than 50 years  More than 50 years
# 62890  Younger than 5 years  More than 50 years  More than 50 years
# 63793                    27                   4  More than 50 years
# 63993  Younger than 5 years  More than 50 years  More than 50 years
# 64288         Older than 85  More than 50 years  More than 50 years
#
#                                       LanguageWorkedWith  \
# 640                           HTML/CSS;JavaScript;Python
# 717    Assembly;Bash/Shell/PowerShell;C;C++;JavaScrip...
# 1099             C;C++;Java;Objective-C;Python;Swift;VBA
# 1564      Bash/Shell/PowerShell;Go;HTML/CSS;Java;SQL;VBA
# 2625               C#;HTML/CSS;JavaScript;SQL;TypeScript
# 3069                                                  C#
# 3202   Bash/Shell/PowerShell;C;C++;HTML/CSS;JavaScrip...
# 5446               Bash/Shell/PowerShell;Perl;Python;SQL
# 6964   Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 10710                                                VBA
# 11018       Bash/Shell/PowerShell;C;C#;HTML/CSS;Java;SQL
# 12064                                              R;VBA
# 13619  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 14033                           Assembly;C;C#;JavaScript
# 14348   Bash/Shell/PowerShell;C++;Java;JavaScript;Python
# 17911  Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;P...
# 18246                                             C#;SQL
# 19706                        Bash/Shell/PowerShell;C;C++
# 24722                                                C++
# 25796  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 26962  Bash/Shell/PowerShell;C;HTML/CSS;Java;JavaScri...
# 27098  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 29732  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 33617  Assembly;Bash/Shell/PowerShell;C;C++;Haskell;H...
# 34551        Bash/Shell/PowerShell;C;C++;HTML/CSS;Python
# 37797                                                NaN
# 39170  Assembly;Bash/Shell/PowerShell;C;C#;C++;Julia;...
# 41822  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 42328                                                NaN
# 44735  Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# 45732                                                NaN
# 45753  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 46677                                  Assembly;C;Python
# 50908                     Bash/Shell/PowerShell;C;Python
# 52363  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 52768  Assembly;Bash/Shell/PowerShell;C;Java;JavaScri...
# 52950  Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;Java;J...
# 56507                                                NaN
# 62890                                                NaN
# 63793                                                NaN
# 63993                                                NaN
# 64288                                                NaN
#
#                                   LanguageDesireNextYear  \
# 640                                                Julia
# 717        Bash/Shell/PowerShell;C;JavaScript;Python;SQL
# 1099             C;C++;Java;Objective-C;Python;Swift;VBA
# 1564                                                 NaN
# 2625                                                 NaN
# 3069                                              C#;C++
# 3202                                               Swift
# 5446                                          Python;SQL
# 6964   Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 10710                                                NaN
# 11018       Bash/Shell/PowerShell;C;C#;HTML/CSS;Java;SQL
# 12064                                              R;VBA
# 13619  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 14033                                         Assembly;C
# 14348   Bash/Shell/PowerShell;C++;Java;JavaScript;Python
# 17911     HTML/CSS;JavaScript;Kotlin;Ruby;SQL;TypeScript
# 18246                                             C#;SQL
# 19706           Bash/Shell/PowerShell;C;C++;Python;Swift
# 24722                                                C++
# 25796                                                NaN
# 26962                                 Dart;Go;TypeScript
# 27098  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 29732                  HTML/CSS;JavaScript;PHP;SQL;Swift
# 33617                                                NaN
# 34551                                           Assembly
# 37797                                                NaN
# 39170                                        Objective-C
# 41822  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 42328                                                NaN
# 44735         C#;C++;HTML/CSS;Java;JavaScript;Python;SQL
# 45732                                                NaN
# 45753  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 46677                                  Assembly;C;Python
# 50908                     Bash/Shell/PowerShell;C;Python
# 52363  Assembly;Bash/Shell/PowerShell;C#;C++;HTML/CSS...
# 52768                                   Python;Ruby;Rust
# 52950  Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;Java;J...
# 56507                                                NaN
# 62890                                                NaN
# 63793  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 63993                                                NaN
# 64288                                                NaN
#
#                    NEWLearn  \
# 640             Once a year
# 717             Once a year
# 1099            Once a year
# 1564       Every few months
# 2625            Once a year
# 3069   Once every few years
# 3202                    NaN
# 5446       Every few months
# 6964   Once every few years
# 10710         Once a decade
# 11018  Once every few years
# 12064                   NaN
# 13619           Once a year
# 14033         Once a decade
# 14348                   NaN
# 17911      Every few months
# 18246  Once every few years
# 19706  Once every few years
# 24722                   NaN
# 25796      Every few months
# 26962      Every few months
# 27098           Once a year
# 29732           Once a year
# 33617      Every few months
# 34551      Every few months
# 37797                   NaN
# 39170         Once a decade
# 41822                   NaN
# 42328                   NaN
# 44735      Every few months
# 45732                   NaN
# 45753      Every few months
# 46677  Once every few years
# 50908           Once a year
# 52363                   NaN
# 52768      Every few months
# 52950      Every few months
# 56507                   NaN
# 62890                   NaN
# 63793           Once a year
# 63993                   NaN
# 64288                   NaN
#
#                                                 NEWStuck  \
# 640    Visit Stack Overflow;Go for a walk or other ph...
# 717    Visit Stack Overflow;Watch help / tutorial videos
# 1099   Visit Stack Overflow;Go for a walk or other ph...
# 1564   Call a coworker or friend;Watch help / tutoria...
# 2625   Meditate;Play games;Call a coworker or friend;...
# 3069   Visit Stack Overflow;Go for a walk or other ph...
# 3202                                Visit Stack Overflow
# 5446   Visit Stack Overflow;Watch help / tutorial videos
# 6964   Meditate;Play games;Call a coworker or friend;...
# 10710                                         Play games
# 11018                               Visit Stack Overflow
# 12064                                                NaN
# 13619  Visit Stack Overflow;Go for a walk or other ph...
# 14033  Visit Stack Overflow;Watch help / tutorial videos
# 14348  Call a coworker or friend;Visit Stack Overflow...
# 17911  Visit Stack Overflow;Go for a walk or other ph...
# 18246  Go for a walk or other physical activity;Do ot...
# 19706  Meditate;Go for a walk or other physical activ...
# 24722                                                NaN
# 25796  Meditate;Play games;Call a coworker or friend;...
# 26962  Meditate;Go for a walk or other physical activ...
# 27098  Visit Stack Overflow;Watch help / tutorial vid...
# 29732  Visit Stack Overflow;Go for a walk or other ph...
# 33617  Meditate;Call a coworker or friend;Go for a wa...
# 34551                                                NaN
# 37797                                                NaN
# 39170  Meditate;Play games;Call a coworker or friend;...
# 41822  Meditate;Play games;Call a coworker or friend;...
# 42328                                                NaN
# 44735                               Visit Stack Overflow
# 45732                                                NaN
# 45753  Meditate;Play games;Call a coworker or friend;...
# 46677  Meditate;Go for a walk or other physical activity
# 50908  Call a coworker or friend;Visit Stack Overflow...
# 52363  Visit Stack Overflow;Watch help / tutorial vid...
# 52768  Call a coworker or friend;Visit Stack Overflow...
# 52950  Meditate;Visit Stack Overflow;Go for a walk or...
# 56507                                                NaN
# 62890                                                NaN
# 63793                                                NaN
# 63993                                                NaN
# 64288                                                NaN
#
#                                               Employment  \
# 640    Independent contractor, freelancer, or self-em...
# 717    Independent contractor, freelancer, or self-em...
# 1099   Independent contractor, freelancer, or self-em...
# 1564                                  Employed full-time
# 2625                                  Employed full-time
# 3069                                  Employed full-time
# 3202   Independent contractor, freelancer, or self-em...
# 5446                                  Employed full-time
# 6964   Independent contractor, freelancer, or self-em...
# 10710                                 Employed full-time
# 11018                                 Employed full-time
# 12064  Independent contractor, freelancer, or self-em...
# 13619  Independent contractor, freelancer, or self-em...
# 14033                                 Employed full-time
# 14348  Independent contractor, freelancer, or self-em...
# 17911  Independent contractor, freelancer, or self-em...
# 18246                                 Employed full-time
# 19706  Independent contractor, freelancer, or self-em...
# 24722                                 Employed full-time
# 25796                                 Employed full-time
# 26962                                 Employed full-time
# 27098  Independent contractor, freelancer, or self-em...
# 29732  Independent contractor, freelancer, or self-em...
# 33617  Independent contractor, freelancer, or self-em...
# 34551                                 Employed full-time
# 37797                                 Employed full-time
# 39170                                 Employed part-time
# 41822                                 Employed full-time
# 42328                                 Employed full-time
# 44735  Independent contractor, freelancer, or self-em...
# 45732                                 Employed full-time
# 45753                                 Employed full-time
# 46677  Independent contractor, freelancer, or self-em...
# 50908                                 Employed full-time
# 52363  Independent contractor, freelancer, or self-em...
# 52768                                 Employed full-time
# 52950  Independent contractor, freelancer, or self-em...
# 56507                                 Employed full-time
# 62890                                 Employed full-time
# 63793                                 Employed full-time
# 63993                                 Employed full-time
# 64288                                 Employed part-time
#
#                                                  DevType  WorkWeekHrs  \
# 640    Designer;Developer, back-end;Developer, deskto...         40.0
# 717    Database administrator;Designer;Developer, bac...         40.0
# 1099   Academic researcher;Data or business analyst;D...          NaN
# 1564                               Developer, full-stack         40.0
# 2625                               Developer, full-stack         40.0
# 3069   Developer, desktop or enterprise applications;...         50.0
# 3202   Database administrator;Designer;Developer, bac...         50.0
# 5446          Database administrator;Developer, back-end         50.0
# 6964   Academic researcher;Data or business analyst;D...        160.0
# 10710                                Academic researcher          NaN
# 11018  Designer;Developer, desktop or enterprise appl...         60.0
# 12064  Data scientist or machine learning specialist;...         50.0
# 13619  Data or business analyst;Database administrato...         32.0
# 14033  Designer;Developer, desktop or enterprise appl...         45.0
# 14348                                          Scientist         30.0
# 17911  Data or business analyst;Developer, back-end;D...         20.0
# 18246  Developer, desktop or enterprise applications;...         38.0
# 19706  Academic researcher;Data scientist or machine ...         15.0
# 24722  Designer;Developer, desktop or enterprise appl...         40.0
# 25796  Academic researcher;Data or business analyst;D...          NaN
# 26962  Academic researcher;Data or business analyst;D...          NaN
# 27098  Developer, back-end;Developer, desktop or ente...         20.0
# 29732  Database administrator;Designer;Developer, bac...         50.0
# 33617                                Senior executive/VP        140.0
# 34551        Developer, embedded applications or devices         60.0
# 37797  Academic researcher;Data or business analyst;D...          NaN
# 39170  Academic researcher;Data or business analyst;D...          NaN
# 41822  Developer, back-end;Developer, mobile;Develope...          NaN
# 42328                                                NaN          1.0
# 44735  Data or business analyst;Database administrato...         60.0
# 45732                                                NaN          NaN
# 45753  Academic researcher;Data or business analyst;D...        168.0
# 46677  Developer, embedded applications or devices;En...         40.0
# 50908                                                NaN         40.0
# 52363  Developer, back-end;Developer, desktop or ente...         20.0
# 52768                                Developer, back-end          NaN
# 52950  Academic researcher;Data or business analyst;D...         30.0
# 56507  Academic researcher;Data or business analyst;D...          NaN
# 62890  Database administrator;Developer, back-end;Dev...          NaN
# 63793                               System administrator          NaN
# 63993                                                NaN          NaN
# 64288                                                NaN          NaN
#
#                                    JobSat  \
# 640                    Slightly satisfied
# 717    Neither satisfied nor dissatisfied
# 1099                                  NaN
# 1564                   Slightly satisfied
# 2625                       Very satisfied
# 3069                       Very satisfied
# 3202                       Very satisfied
# 5446                    Very dissatisfied
# 6964   Neither satisfied nor dissatisfied
# 10710                      Very satisfied
# 11018                   Very dissatisfied
# 12064                   Very dissatisfied
# 13619                      Very satisfied
# 14033                      Very satisfied
# 14348                  Slightly satisfied
# 17911                      Very satisfied
# 18246                      Very satisfied
# 19706                      Very satisfied
# 24722               Slightly dissatisfied
# 25796                      Very satisfied
# 26962                                 NaN
# 27098                      Very satisfied
# 29732                      Very satisfied
# 33617                      Very satisfied
# 34551                   Very dissatisfied
# 37797                   Very dissatisfied
# 39170  Neither satisfied nor dissatisfied
# 41822  Neither satisfied nor dissatisfied
# 42328  Neither satisfied nor dissatisfied
# 44735                      Very satisfied
# 45732                                 NaN
# 45753                      Very satisfied
# 46677                      Very satisfied
# 50908                   Very dissatisfied
# 52363                      Very satisfied
# 52768                      Very satisfied
# 52950                      Very satisfied
# 56507                      Very satisfied
# 62890                                 NaN
# 63793                   Very dissatisfied
# 63993                   Very dissatisfied
# 64288                                 NaN
#
#                                               JobFactors  \
# 640    Flex time or a flexible schedule;Remote work o...
# 717    Remote work options;Opportunities for professi...
# 1099                                                 NaN
# 1564   Languages, frameworks, and other technologies ...
# 2625   Flex time or a flexible schedule;Languages, fr...
# 3069   Flex time or a flexible schedule;Languages, fr...
# 3202   Flex time or a flexible schedule;Languages, fr...
# 5446   Languages, frameworks, and other technologies ...
# 6964   Financial performance or funding status of the...
# 10710                                                NaN
# 11018  Office environment or company culture;Opportun...
# 12064  Industry that I’d be working in;Office environ...
# 13619  Flex time or a flexible schedule;Specific depa...
# 14033                                                NaN
# 14348  Languages, frameworks, and other technologies ...
# 17911  Languages, frameworks, and other technologies ...
# 18246         Opportunities for professional development
# 19706  Industry that I’d be working in;Languages, fra...
# 24722  Flex time or a flexible schedule;Languages, fr...
# 25796  Languages, frameworks, and other technologies ...
# 26962                                                NaN
# 27098  Languages, frameworks, and other technologies ...
# 29732  Languages, frameworks, and other technologies ...
# 33617                    Industry that I’d be working in
# 34551  Diversity of the company or organization;Oppor...
# 37797                                                NaN
# 39170                                                NaN
# 41822  Remote work options;Financial performance or f...
# 42328                                                NaN
# 44735  Flex time or a flexible schedule;Languages, fr...
# 45732                                                NaN
# 45753  Languages, frameworks, and other technologies ...
# 46677  Industry that I’d be working in;Languages, fra...
# 50908  Languages, frameworks, and other technologies ...
# 52363  Flex time or a flexible schedule;Languages, fr...
# 52768  Financial performance or funding status of the...
# 52950  Industry that I’d be working in;Languages, fra...
# 56507                                                NaN
# 62890                                                NaN
# 63793                    Industry that I’d be working in
# 63993                                                NaN
# 64288                                                NaN
#
#                                              NEWOvertime  \
# 640                     Often: 1-2 days per week or more
# 717    Sometimes: 1-2 days per month but less than we...
# 1099                                                 NaN
# 1564                   Rarely: 1-2 days per year or less
# 2625                                               Never
# 3069                    Often: 1-2 days per week or more
# 3202                    Often: 1-2 days per week or more
# 5446                    Often: 1-2 days per week or more
# 6964   Occasionally: 1-2 days per quarter but less th...
# 10710                                              Never
# 11018                   Often: 1-2 days per week or more
# 12064                   Often: 1-2 days per week or more
# 13619                   Often: 1-2 days per week or more
# 14033                                                NaN
# 14348                                              Never
# 17911  Occasionally: 1-2 days per quarter but less th...
# 18246  Occasionally: 1-2 days per quarter but less th...
# 19706                   Often: 1-2 days per week or more
# 24722                   Often: 1-2 days per week or more
# 25796                   Often: 1-2 days per week or more
# 26962                                                NaN
# 27098  Occasionally: 1-2 days per quarter but less th...
# 29732                   Often: 1-2 days per week or more
# 33617                   Often: 1-2 days per week or more
# 34551                   Often: 1-2 days per week or more
# 37797                                              Never
# 39170                                                NaN
# 41822                                              Never
# 42328                                              Never
# 44735                   Often: 1-2 days per week or more
# 45732                                                NaN
# 45753                   Often: 1-2 days per week or more
# 46677                   Often: 1-2 days per week or more
# 50908  Sometimes: 1-2 days per month but less than we...
# 52363  Sometimes: 1-2 days per month but less than we...
# 52768  Sometimes: 1-2 days per month but less than we...
# 52950                   Often: 1-2 days per week or more
# 56507                                                NaN
# 62890                                                NaN
# 63793  Occasionally: 1-2 days per quarter but less th...
# 63993                                                NaN
# 64288                                                NaN
#
#                                 NEWEdImpt
# 640                    Somewhat important
# 717                    Somewhat important
# 1099                 Critically important
# 1564                       Very important
# 2625                   Somewhat important
# 3069                     Fairly important
# 3202                   Somewhat important
# 5446                   Somewhat important
# 6964                 Critically important
# 10710                                 NaN
# 11018  Not at all important/not necessary
# 12064                Critically important
# 13619                    Fairly important
# 14033                    Fairly important
# 14348                Critically important
# 17911  Not at all important/not necessary
# 18246                Critically important
# 19706                      Very important
# 24722                Critically important
# 25796                  Somewhat important
# 26962  Not at all important/not necessary
# 27098                      Very important
# 29732                      Very important
# 33617                Critically important
# 34551                      Very important
# 37797                      Very important
# 39170  Not at all important/not necessary
# 41822                                 NaN
# 42328  Not at all important/not necessary
# 44735                  Somewhat important
# 45732                Critically important
# 45753  Not at all important/not necessary
# 46677  Not at all important/not necessary
# 50908                  Somewhat important
# 52363                      Very important
# 52768  Not at all important/not necessary
# 52950                Critically important
# 56507                                 NaN
# 62890                                 NaN
# 63793                  Somewhat important
# 63993  Not at all important/not necessary
# 64288  Not at all important/not necessary

# %%
sdf[sdf['Age1stCode']=='Younger than 5 years']
# Out:
#              Country   Age                                             Gender  \
# 209    United States  34.0  Non-binary, genderqueer, or gender non-conforming
# 372           Canada  40.0                                                Man
# 534           Canada  36.0                                                Man
# 566    United States  36.0                                                Man
# 634    United States  28.0                                                Man
# ...              ...   ...                                                ...
# 64383      Indonesia   1.0                                              Woman
# 64401         Poland   NaN                                              Woman
# 64412       Djibouti   NaN                                                Man
# 64421     Costa Rica  17.0  Non-binary, genderqueer, or gender non-conforming
# 64438        Morocco   NaN                                                Man
#
#                                                  EdLevel  \
# 209         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 372      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 534         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 566    Secondary school (e.g. American high school, G...
# 634         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 64383             I never completed any formal education
# 64401             I never completed any formal education
# 64412             I never completed any formal education
# 64421  Secondary school (e.g. American high school, G...
# 64438                          Primary/elementary school
#
#                                           UndergradMajor Hobbyist  \
# 209    A social science (such as anthropology, psycho...      Yes
# 372    Computer science, computer engineering, or sof...      Yes
# 534    Another engineering discipline (such as civil,...      Yes
# 566                                                  NaN      Yes
# 634    Another engineering discipline (such as civil,...      Yes
# ...                                                  ...      ...
# 64383                                                NaN      Yes
# 64401                                                NaN      Yes
# 64412                                                NaN      Yes
# 64421                                                NaN      Yes
# 64438                                                NaN      Yes
#
#                  Age1stCode         YearsCode      YearsCodePro  \
# 209    Younger than 5 years                 6                 5
# 372    Younger than 5 years                35                20
# 534    Younger than 5 years                30                 7
# 566    Younger than 5 years                25                13
# 634    Younger than 5 years                26                 7
# ...                     ...               ...               ...
# 64383  Younger than 5 years                 1                 1
# 64401  Younger than 5 years  Less than 1 year               NaN
# 64412  Younger than 5 years  Less than 1 year  Less than 1 year
# 64421  Younger than 5 years                14               NaN
# 64438  Younger than 5 years  Less than 1 year  Less than 1 year
#
#                                       LanguageWorkedWith  \
# 209                      Bash/Shell/PowerShell;Go;Python
# 372    Bash/Shell/PowerShell;C#;Go;HTML/CSS;Java;Java...
# 534                                      C#;HTML/CSS;SQL
# 566    Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# 634                                      C;C#;Python;VBA
# ...                                                  ...
# 64383  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64401  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64412                                               Java
# 64421  Assembly;C;C#;C++;Go;HTML/CSS;Java;JavaScript;...
# 64438     C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
#
#                                   LanguageDesireNextYear  \
# 209                      Bash/Shell/PowerShell;Go;Python
# 372               Bash/Shell/PowerShell;Dart;Kotlin;Rust
# 534                                      C#;HTML/CSS;SQL
# 566    Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;R...
# 634                                          C;C#;Python
# ...                                                  ...
# 64383  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64401  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64412                                               Java
# 64421  Bash/Shell/PowerShell;Dart;Haskell;Julia;Rust;...
# 64438                                                NaN
#
#                    NEWLearn  \
# 209             Once a year
# 372             Once a year
# 534    Once every few years
# 566             Once a year
# 634    Once every few years
# ...                     ...
# 64383                   NaN
# 64401  Once every few years
# 64412      Every few months
# 64421                   NaN
# 64438                   NaN
#
#                                                 NEWStuck          Employment  \
# 209    Call a coworker or friend;Visit Stack Overflow...  Employed full-time
# 372    Call a coworker or friend;Visit Stack Overflow...  Employed full-time
# 534    Call a coworker or friend;Visit Stack Overflow...  Employed full-time
# 566    Call a coworker or friend;Visit Stack Overflow...  Employed full-time
# 634    Visit Stack Overflow;Go for a walk or other ph...  Employed full-time
# ...                                                  ...                 ...
# 64383  Meditate;Play games;Call a coworker or friend;...                 NaN
# 64401  Meditate;Play games;Call a coworker or friend;...  Employed full-time
# 64412                                                NaN                 NaN
# 64421  Meditate;Play games;Call a coworker or friend;...             Student
# 64438   Meditate;Play games;Watch help / tutorial videos                 NaN
#
#                                                  DevType  WorkWeekHrs  \
# 209                                  Developer, back-end         35.0
# 372                                  Senior executive/VP         50.0
# 534    Database administrator;Designer;Developer, bac...         45.0
# 566    Developer, back-end;Developer, desktop or ente...         45.0
# 634          Developer, embedded applications or devices         40.0
# ...                                                  ...          ...
# 64383                                                NaN          NaN
# 64401  Academic researcher;Data or business analyst;D...          NaN
# 64412                                                NaN          NaN
# 64421                                                NaN          NaN
# 64438                                                NaN          NaN
#
#                       JobSat  \
# 209    Slightly dissatisfied
# 372           Very satisfied
# 534           Very satisfied
# 566           Very satisfied
# 634           Very satisfied
# ...                      ...
# 64383                    NaN
# 64401                    NaN
# 64412                    NaN
# 64421                    NaN
# 64438                    NaN
#
#                                               JobFactors  \
# 209    Remote work options;Office environment or comp...
# 372    Flex time or a flexible schedule;Office enviro...
# 534    Flex time or a flexible schedule;Office enviro...
# 566    Flex time or a flexible schedule;Languages, fr...
# 634    Industry that I’d be working in;Office environ...
# ...                                                  ...
# 64383                                                NaN
# 64401                                                NaN
# 64412                                                NaN
# 64421                                                NaN
# 64438                                                NaN
#
#                                              NEWOvertime  \
# 209    Sometimes: 1-2 days per month but less than we...
# 372    Sometimes: 1-2 days per month but less than we...
# 534    Sometimes: 1-2 days per month but less than we...
# 566    Occasionally: 1-2 days per quarter but less th...
# 634    Sometimes: 1-2 days per month but less than we...
# ...                                                  ...
# 64383                                                NaN
# 64401                                                NaN
# 64412                                                NaN
# 64421                                                NaN
# 64438                                                NaN
#
#                                 NEWEdImpt
# 209    Not at all important/not necessary
# 372                        Very important
# 534                      Fairly important
# 566                    Somewhat important
# 634                  Critically important
# ...                                   ...
# 64383                                 NaN
# 64401                                 NaN
# 64412                                 NaN
# 64421                                 NaN
# 64438                      Very important
#
# [414 rows x 20 columns]

# %% [markdown]
# **Observation:**
# * YearsCode & YearsCodePro are mostly having same values and this is the difference between  `age - Age1stCode`
# * 'Age1stCode'='Younger than 5 years' seems data entered for fun and seems false entry
# * `Way ahead:` Use error management like, errors='coerce'

# %%
sdf['Age1stCode'] = pd.to_numeric(sdf.Age1stCode, errors='coerce')
sdf['YearsCode'] = pd.to_numeric(sdf.YearsCode, errors='coerce')
sdf['YearsCodePro'] = pd.to_numeric(sdf.YearsCodePro, errors='coerce')

# %%
print(sdf.Age.mean(), sdf.Age.min(), sdf.Age.max())
sdf.Age.hist(bins=30);
# Out:
# 30.83411081283281 1.0 279.0

# %% [markdown]
# There seems to be a problem with the age column, *as the minimum value is 1* and *the maximum is 279*.
# This is a common issue with surveys: responses may contain invalid values due to accidental or intentional errors while responding. A simple fix would be to ignore the rows where the age is higher than 100 years or lower than 10 years as invalid survey responses.
# We can do this using the `.drop` method, [as explained here](https://www.geeksforgeeks.org/drop-rows-from-the-dataframe-based-on-certain-condition-applied-on-a-column/).

# %%
sdf.drop(sdf[sdf.Age < 10].index, inplace=True)
sdf.drop(sdf[sdf.Age > 100].index, inplace=True)

# %%
# The same holds for `WorkWeekHrs`. Let's ignore entries where the value for the column is higher than 140 hours. (~20 hours per day).
sdf.drop(sdf[sdf.WorkWeekHrs > 140].index, inplace=True)

# %% [markdown]
# ##### Lets explore Gender

# %%
sdf['Gender'].value_counts()
# Out:
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: Gender, dtype: int64

# %%
## We will replace gender containing ';' with nan
# Below code will do that
sdf.where(~(sdf.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
sdf.sample(10)
# Out:
#                   Country   Age  \
# 59566              Brazil   NaN
# 55128             Morocco   NaN
# 7489              Germany  30.0
# 7592              Germany  33.0
# 13837         New Zealand  18.0
# 25687       United States  29.0
# 4053        United States  27.0
# 23307              Turkey  40.0
# 10643               Qatar   NaN
# 63661  Russian Federation   NaN
#
#                                                   Gender  \
# 59566                                                Man
# 55128                                                NaN
# 7489                                                 Man
# 7592                                                 Man
# 13837                                                Man
# 25687                                                Man
# 4053                                                 Man
# 23307                                                Man
# 10643  Non-binary, genderqueer, or gender non-conforming
# 63661                                                NaN
#
#                                                  EdLevel  \
# 59566  Secondary school (e.g. American high school, G...
# 55128    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7489     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7592     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 13837                Associate degree (A.A., A.S., etc.)
# 25687       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4053        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23307    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10643       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63661                                                NaN
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 59566                                                NaN      Yes        17.0
# 55128                          Mathematics or statistics      Yes        21.0
# 7489   Computer science, computer engineering, or sof...      Yes        15.0
# 7592   Computer science, computer engineering, or sof...       No        10.0
# 13837  Computer science, computer engineering, or sof...      Yes        15.0
# 25687  Computer science, computer engineering, or sof...      Yes        16.0
# 4053   Computer science, computer engineering, or sof...       No        12.0
# 23307                          Mathematics or statistics       No        17.0
# 10643  Information systems, information technology, o...       No        19.0
# 63661                                                NaN      Yes         NaN
#
#        YearsCode  YearsCodePro  \
# 59566        3.0           NaN
# 55128        NaN           NaN
# 7489        15.0           6.0
# 7592        23.0          10.0
# 13837        4.0           NaN
# 25687       13.0           9.0
# 4053        15.0           6.0
# 23307       23.0           8.0
# 10643       10.0           7.0
# 63661        NaN           NaN
#
#                                       LanguageWorkedWith  \
# 59566  Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 55128                                             Python
# 7489   Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 7592                                                  C#
# 13837          C#;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 25687        Bash/Shell/PowerShell;JavaScript;Python;SQL
# 4053                           HTML/CSS;Scala;TypeScript
# 23307                            HTML/CSS;JavaScript;PHP
# 10643                                   HTML/CSS;PHP;SQL
# 63661                                                NaN
#
#                                   LanguageDesireNextYear  \
# 59566  Bash/Shell/PowerShell;C;C#;C++;Dart;Go;HTML/CS...
# 55128                                             Python
# 7489   Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 7592                                                 NaN
# 13837  Assembly;C#;C++;HTML/CSS;JavaScript;Python;SQL...
# 25687              Bash/Shell/PowerShell;Python;Rust;SQL
# 4053                           HTML/CSS;Scala;TypeScript
# 23307                                         PHP;Python
# 10643                               Go;Objective-C;PHP;R
# 63661                                                NaN
#
#                    NEWLearn  \
# 59566           Once a year
# 55128           Once a year
# 7489   Once every few years
# 7592   Once every few years
# 13837           Once a year
# 25687  Once every few years
# 4053   Once every few years
# 23307      Every few months
# 10643           Once a year
# 63661  Once every few years
#
#                                                 NEWStuck  \
# 59566  Play games;Call a coworker or friend;Visit Sta...
# 55128                       Watch help / tutorial videos
# 7489                                                 NaN
# 7592   Go for a walk or other physical activity;Do ot...
# 13837  Visit Stack Overflow;Watch help / tutorial videos
# 25687  Visit Stack Overflow;Go for a walk or other ph...
# 4053   Visit Stack Overflow;Go for a walk or other ph...
# 23307  Visit Stack Overflow;Go for a walk or other ph...
# 10643                               Visit Stack Overflow
# 63661  Meditate;Go for a walk or other physical activ...
#
#                                               Employment  \
# 59566                                            Student
# 55128                                 Employed full-time
# 7489   Independent contractor, freelancer, or self-em...
# 7592                                  Employed full-time
# 13837                                 Employed part-time
# 25687                                 Employed full-time
# 4053                                  Employed full-time
# 23307                                 Employed full-time
# 10643                                 Employed full-time
# 63661                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 59566                                                NaN          NaN
# 55128      Data scientist or machine learning specialist          NaN
# 7489   Data scientist or machine learning specialist;...         35.0
# 7592   Developer, desktop or enterprise applications;...         45.0
# 13837  Developer, desktop or enterprise applications;...          NaN
# 25687                                                NaN         40.0
# 4053   Developer, back-end;Developer, front-end;Devel...         35.0
# 23307          Developer, back-end;Developer, full-stack         45.0
# 10643                              Developer, full-stack          NaN
# 63661                                                NaN          NaN
#
#                                    JobSat  \
# 59566                                 NaN
# 55128                                 NaN
# 7489                       Very satisfied
# 7592                   Slightly satisfied
# 13837                                 NaN
# 25687               Slightly dissatisfied
# 4053                       Very satisfied
# 23307               Slightly dissatisfied
# 10643  Neither satisfied nor dissatisfied
# 63661                                 NaN
#
#                                               JobFactors  \
# 59566  Industry that I’d be working in;Flex time or a...
# 55128                                                NaN
# 7489   Flex time or a flexible schedule;Remote work o...
# 7592   Industry that I’d be working in;Diversity of t...
# 13837  Industry that I’d be working in;Office environ...
# 25687  Languages, frameworks, and other technologies ...
# 4053   Flex time or a flexible schedule;Remote work o...
# 23307  Flex time or a flexible schedule;Specific depa...
# 10643                                                NaN
# 63661                                                NaN
#
#                                              NEWOvertime  \
# 59566                                                NaN
# 55128                                                NaN
# 7489                   Rarely: 1-2 days per year or less
# 7592                    Often: 1-2 days per week or more
# 13837                                                NaN
# 25687  Sometimes: 1-2 days per month but less than we...
# 4053                   Rarely: 1-2 days per year or less
# 23307                   Often: 1-2 days per week or more
# 10643                                              Never
# 63661                                                NaN
#
#                                 NEWEdImpt
# 59566                                 NaN
# 55128  Not at all important/not necessary
# 7489                       Very important
# 7592                       Very important
# 13837                                 NaN
# 25687                      Very important
# 4053                     Fairly important
# 23307  Not at all important/not necessary
# 10643                    Fairly important
# 63661                                 NaN

# %% [markdown]
# There are still many columns with NaN value
#  we can remove rows with more than 10 rows having NaN value

# %% [markdown]
# # Exploratory Analysis and Visualization
#
# Before we ask questions about the survey responses, it would help to understand the respondents' demographics, i.e., country, age, gender, education level, employment level, etc. It's essential to explore these variables to understand how representative the survey is of the worldwide programming community. A survey of this scale generally tends to have some [selection bias](https://en.wikipedia.org/wiki/Selection_bias).
#
# Let's begin by importing `matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('whitegrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
###############~~~~~~~~~~~~ Creating Custom Color Palette ~~~~~~~~~~~~###############
#24477f : Mck deep blue
#0892d0 : Mck electric blue
#66b3ff : light blue

mck_color2 = sns.color_palette(['#0892d0', '#24477f'])
mck_color3 = sns.color_palette(['#0892d0', '#24477f', 'black'])
mck_color = sns.blend_palette(['#0892d0', '#24477f','black'],9)
mck_color12 = sns.blend_palette(['#0892d0', '#24477f','black'],12)
mck_color25 = sns.blend_palette(['#41aad9','#0892d0', '#24477f','black'],25)
sns.color_palette('Blues')
sns.color_palette(mck_color3)
# Out:
# [(0.03137254901960784, 0.5725490196078431, 0.8156862745098039),
#  (0.1411764705882353, 0.2784313725490196, 0.4980392156862745),
#  (0.0, 0.0, 0.0)]

# %% [markdown]
# ## `Country`
#
# Let's look at the number of countries from which there are responses in the survey and plot the ten countries with the highest number of responses.

# %%
top_countries = sdf.Country.value_counts().head(15)

plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title(schema.Country)
sns.barplot(x=top_countries.index, y=top_countries, palette='Blues_r');

# %% [markdown]
# It appears that a disproportionately high number of respondents are from the US and India, probably because the survey is in English, and these countries have the highest English-speaking populations. We can already see that the survey may not be representative of the global programming community - especially from non-English speaking countries. Programmers from non-English speaking countries are almost certainly underrepresented.
# ***Conclusion***
# As **40% surveyees are from `USA`,`India`, `UK`**. This indicates this survey `bias towards english speaking nation`
#
# **Way ahead for survey**:
# Survey should be conducted in multiple language so to encorage participation from non-english speaking countries

# %% [markdown]
# ## `Age`
#
# The distribution of respondents' age is another crucial factor to look at. We can use a histogram to visualize it.

# %%
plt.figure(figsize=(12, 6))
plt.title(schema.Age)
plt.xlabel('Age')
plt.ylabel('Probability Density')
sns.distplot(sdf.Age , color='blue', rug=True, rug_kws = { 'height': 0.05, 'color': 'xkcd:navy'}, kde_kws={'lw':2, 'color': 'xkcd:navy', 'bw':0.08} )
plt.show();
print('Mean Age is: ', sdf.Age.mean())
# 'lw' Thickness of kde plot 
# 'bw' Bandwidth controls the smoothness of kdplot
# By default rug is false
# Out:
# Mean Age is:  30.84292624478566

# %% [markdown]
# It appears that a large percentage of respondents are `20-45 years old`. It's somewhat representative of the programming community in general. Many young people have taken up computer science as their field of study or profession in the last 20 years.
#
# `Note:` The x-axis is the value of the variable just like in a histogram, but what exactly does the y-axis represent?
# **ANS->** The y-axis in a density plot is the probability density function for the kernel density estimation. However, we need to be careful to specify this is a probability density and not a probability. The difference is the probability density is the probability per unit on the x-axis. To convert to an actual probability, we need to find the area under the curve for a specific interval on the x-axis. Somewhat confusingly, because this is a probability density and not a probability, the y-axis can take values greater than one. The only requirement of the density plot is that the total area under the curve integrates to one. I generally tend to think of the y-axis on a density plot as a value only for relative comparisons between different categories.
# for [reference](https://towardsdatascience.com/histograms-and-density-plots-in-python-f6bda88f5ac0)
#
#
# ## `Gender`
#
# Let's look at the distribution of responses for the Gender. It's a well-known fact that women and non-binary genders are underrepresented in the programming community, so we might expect to see a skewed distribution here.

# %%
schema.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
gender_counts = sdf.Gender.value_counts()
gender_counts
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
# Pie chart
###### Use when trying to COMPARE A CATEGORY or GROUP OF CATEGORIES to the TOTAL  #########
labels = gender_counts.index 
sizes = gender_counts
#colors
colors = ['#24477f','#0892d0','#66b3ff']
#explsion
explode = (0.05,0.05,0.075)
plt.figure(figsize=(12,6))
plt.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=180, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle  
plt.title(schema.Gender)
plt.tight_layout()
plt.show()

# %% [markdown]
# Only about 8% of survey respondents who have answered the question identify as women or non-binary. This number is lower than the overall percentage of women & non-binary genders in the programming community - which is estimated to be around 12%.
#
# **Intresting**: This EDA notebook express `Gender Divide in Data Science Roles` [Gender Divide in Data Science](https://medium.com/datadriveninvestor/exploratory-data-analysis-eda-understanding-the-gender-divide-in-data-science-roles-9faa5da44f5b)
#
# ## `Education Level`
#
# Formal education in computer science is often considered an essential requirement for becoming a programmer. However, there are many free resources & tutorials available online to learn programming. Let's compare the education levels of respondents to gain some insight into this. We'll use a horizontal bar plot here.

# %%
z=sdf.EdLevel
sns.countplot(y= z, palette=mck_color)
plt.xticks(rotation=75);
plt.title(schema['EdLevel'])
plt.ylabel(None);

# %% [markdown]
# It appears that well **over half of the respondents hold a bachelor's or master's degree**, so `most programmers seem to have some college education.` However, it's not clear from this graph alone if they hold a degree in computer science.

# %%
schema.UndergradMajor
# Out:
# 'What was your primary field of study?'

# %%
undergrad_pct = sdf.UndergradMajor.value_counts() * 100 / sdf.UndergradMajor.count()

sns.barplot(x=undergrad_pct, y=undergrad_pct.index, palette= mck_color12)

plt.title(schema.UndergradMajor)
plt.ylabel(None);
plt.xlabel('Percentage');

# %% [markdown]
# It turns out that 40% of programmers holding a college degree have a field of study other than computer science - which is very encouraging. It seems to suggest that while a college education is helpful in general, you do not need to pursue a major in computer science to become a successful programmer.
#
# **Way ahead**: Analyze the `NEWEdImpt` column for respondents who hold some college degree vs. those who don't. Do you notice any difference in opinion?

# %% [markdown]
# ## `NEWEdImpt`

# %%
schema.NEWEdImpt
# Out:
# 'How important is a formal education, such as a university degree in computer science, to your career?'

# %%
sdf.NEWEdImpt.value_counts()
# Out:
# Fairly important                      12588
# Very important                        11783
# Somewhat important                    11298
# Not at all important/not necessary     7707
# Critically important                   4716
# Name: NEWEdImpt, dtype: int64

# %%
a=sdf.EdLevel
b=sdf.NEWEdImpt
temp= pd.concat([a,b],axis=1)
temp.dropna(inplace=True)
temp[temp['NEWEdImpt']=='Fairly important'].value_counts()
# Out:
# EdLevel                                                                             NEWEdImpt
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                        Fairly important    6767
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                     Fairly important    3425
# Some college/university study without earning a degree                              Fairly important     971
# Associate degree (A.A., A.S., etc.)                                                 Fairly important     368
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)  Fairly important     328
# Other doctoral degree (Ph.D., Ed.D., etc.)                                          Fairly important     303
# Professional degree (JD, MD, etc.)                                                  Fairly important     175
# Primary/elementary school                                                           Fairly important      41
# dtype: int64

# %%
temp[temp['NEWEdImpt']=='Not at all important/not necessary'].value_counts()
# Out:
# EdLevel                                                                             NEWEdImpt
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                        Not at all important/not necessary    2767
# Some college/university study without earning a degree                              Not at all important/not necessary    2060
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)  Not at all important/not necessary     986
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                     Not at all important/not necessary     914
# Associate degree (A.A., A.S., etc.)                                                 Not at all important/not necessary     394
# Primary/elementary school                                                           Not at all important/not necessary     139
# Other doctoral degree (Ph.D., Ed.D., etc.)                                          Not at all important/not necessary     112
# Professional degree (JD, MD, etc.)                                                  Not at all important/not necessary     109
# dtype: int64

# %%
temp[temp['EdLevel']=='Bachelor’s degree (B.A., B.S., B.Eng., etc.)'].value_counts()
# Out:
# EdLevel                                       NEWEdImpt
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Fairly important                      6767
#                                               Very important                        5944
#                                               Somewhat important                    5559
#                                               Not at all important/not necessary    2767
#                                               Critically important                  2145
# dtype: int64

# %%
temp[temp['EdLevel']=='Bachelor’s degree (B.A., B.S., B.Eng., etc.)'].value_counts()
# Out:
# EdLevel                                       NEWEdImpt
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Fairly important                      6767
#                                               Very important                        5944
#                                               Somewhat important                    5559
#                                               Not at all important/not necessary    2767
#                                               Critically important                  2145
# dtype: int64

# %% [markdown]
# #### Analyse with respect to **UndergradMajor**

# %% [markdown]
# ## `Employment`
#
# Freelancing or contract work is a common choice among programmers, so it would be interesting to compare the breakdown between full-time, part-time, and freelance work. Let's visualize the data from the `Employment` column.

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
(sdf.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color= mck_color)
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %% [markdown]
# It appears that close to 10% of respondents are employed part time or as freelancers.
#
# **Exercise**: Add a new column `EmploymentType` containing the values `Enthusiast` (student or not employed but looking for work), `Professional` (employed full-time, part-time or freelancing), and `Other` (not employed or retired). For each of the graphs that follow, show a comparison between `Enthusiast` and `Professional`.

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
sdf.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                           4396
# Developer, back-end                                                                                                                                                             3056
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                  2214
# Developer, back-end;Developer, full-stack                                                                                                                                       1465
# Developer, front-end                                                                                                                                                            1390
#                                                                                                                                                                                 ...
# Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test;Senior executive/VP                                                    1
# Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Product manager;Senior executive/VP                                                          1
# Developer, back-end;Developer, full-stack;Developer, mobile;DevOps specialist;Educator;System administrator                                                                        1
# Data or business analyst;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, mobile;Engineering manager       1
# Data or business analyst;Developer, mobile;Senior executive/VP;System administrator                                                                                                1
# Name: DevType, Length: 8213, dtype: int64

# %%
## Creating a function for Feature Engineering

def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
dev_type_df = split_multicolumn(sdf.DevType)

# %%
dev = dev_type_df.copy()
dev_type_df
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
#        Developer, mobile  Designer  Developer, front-end  Developer, back-end  \
# 0                  False     False                 False                False
# 1                   True     False                 False                False
# 2                  False     False                 False                False
# 3                  False     False                 False                False
# 4                  False     False                 False                False
# ...                  ...       ...                   ...                  ...
# 64456              False     False                 False                False
# 64457              False     False                 False                False
# 64458              False     False                 False                False
# 64459              False     False                 False                False
# 64460              False     False                 False                False
#
#        Developer, QA or test  DevOps specialist  Developer, game or graphics  \
# 0                      False              False                        False
# 1                      False              False                        False
# 2                      False              False                        False
# 3                      False              False                        False
# 4                      False              False                        False
# ...                      ...                ...                          ...
# 64456                  False              False                        False
# 64457                  False              False                        False
# 64458                  False              False                        False
# 64459                  False              False                        False
# 64460                  False              False                        False
#
#        Database administrator  Developer, embedded applications or devices  \
# 0                       False                                        False
# 1                       False                                        False
# 2                       False                                        False
# 3                       False                                        False
# 4                       False                                        False
# ...                       ...                                          ...
# 64456                   False                                        False
# 64457                   False                                        False
# 64458                   False                                        False
# 64459                   False                                        False
# 64460                   False                                        False
#
#        Engineer, data  Educator  System administrator  Engineering manager  \
# 0               False     False                 False                False
# 1               False     False                 False                False
# 2               False     False                 False                False
# 3               False     False                 False                False
# 4               False     False                 False                False
# ...               ...       ...                   ...                  ...
# 64456           False     False                 False                False
# 64457           False     False                 False                False
# 64458           False     False                 False                False
# 64459           False     False                 False                False
# 64460           False     False                 False                False
#
#        Product manager  Data or business analyst  Academic researcher  \
# 0                False                     False                False
# 1                False                     False                False
# 2                False                     False                False
# 3                False                     False                False
# 4                False                     False                False
# ...                ...                       ...                  ...
# 64456            False                     False                False
# 64457            False                     False                False
# 64458            False                     False                False
# 64459            False                     False                False
# 64460            False                     False                False
#
#        Data scientist or machine learning specialist  Scientist  \
# 0                                              False      False
# 1                                              False      False
# 2                                              False      False
# 3                                              False      False
# 4                                              False      False
# ...                                              ...        ...
# 64456                                          False      False
# 64457                                          False      False
# 64458                                          False      False
# 64459                                          False      False
# 64460                                          False      False
#
#        Senior executive/VP  Engineer, site reliability  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 3                    False                       False
# 4                    False                       False
# ...                    ...                         ...
# 64456                 True                       False
# 64457                False                       False
# 64458                False                       False
# 64459                False                       False
# 64460                False                       False
#
#        Marketing or sales professional
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 64456                            False
# 64457                            False
# 64458                            False
# 64459                            False
# 64460                            False
#
# [64306 rows x 23 columns]

# %% [markdown]
# The `dev_type_df` has one column for each option that can be selected as a response. If a respondent has chosen an option, the corresponding column's value is `True`. Otherwise, it is `False`.
#
# We can now use the column-wise totals to identify the most common roles.

# %%
dev_type_totals = dev_type_df.sum().sort_values(ascending=False)
dev_type_totals
# Out:
# Developer, back-end                              26996
# Developer, full-stack                            26915
# Developer, front-end                             18128
# Developer, desktop or enterprise applications    11687
# Developer, mobile                                 9406
# DevOps specialist                                 5915
# Database administrator                            5658
# Designer                                          5262
# System administrator                              5185
# Developer, embedded applications or devices       4701
# Data or business analyst                          3970
# Data scientist or machine learning specialist     3939
# Developer, QA or test                             3893
# Engineer, data                                    3700
# Academic researcher                               3502
# Educator                                          2895
# Developer, game or graphics                       2751
# Engineering manager                               2699
# Product manager                                   2471
# Scientist                                         2060
# Engineer, site reliability                        1921
# Senior executive/VP                               1292
# Marketing or sales professional                    625
# dtype: int64

# %% [markdown]
# As one might expect, the most common roles include "Developer" in the name.
#
# **Way ahead**:
#
# * Figure out what percentage of respondents work in roles related to data science?
# * Which positions have the highest percentage of women?

# %%
dev_type_prc = dev_type_df.mean().sort_values(ascending=False)*100
display(dev_type_prc )
# Out:
# Developer, back-end                              41.980531
# Developer, full-stack                            41.854570
# Developer, front-end                             28.190216
# Developer, desktop or enterprise applications    18.174043
# Developer, mobile                                14.626940
# DevOps specialist                                 9.198209
# Database administrator                            8.798557
# Designer                                          8.182751
# System administrator                              8.063011
# Developer, embedded applications or devices       7.310360
# Data or business analyst                          6.173607
# Data scientist or machine learning specialist     6.125400
# Developer, QA or test                             6.053867
# Engineer, data                                    5.753740
# Academic researcher                               5.445837
# Educator                                          4.501913
# Developer, game or graphics                       4.277983
# Engineering manager                               4.197120
# Product manager                                   3.842565
# Scientist                                         3.203434
# Engineer, site reliability                        2.987280
# Senior executive/VP                               2.009144
# Marketing or sales professional                   0.971916
# dtype: float64

# %%
### Creating custom color for this visualization
custom = sns.color_palette(mck_color25)
custom[10] = '#ff781f'
custom[11] = '#ff6600'

### visualization the data 

plt.figure(figsize=(12, 12))
sns.barplot(x=dev_type_prc, y=dev_type_prc.index, palette= custom)
plt.title("Roles held by the respondents");
plt.xlabel('Percentage');

# %%
## Which positions have the highest percentage of women?

dev['Gender']= sdf['Gender']
dev.dropna(inplace=True)
gen_dev= dev.groupby('Gender').sum().T
a= gen_dev['Man']
b= gen_dev['Non-binary, genderqueer, or gender non-conforming']
gen_dev['Man']= gen_dev['Man']/(gen_dev['Man'] + gen_dev['Non-binary, genderqueer, or gender non-conforming']+ gen_dev['Woman'])*100
gen_dev['Non-binary, genderqueer, or gender non-conforming'] = b/(a+b+gen_dev['Woman'])*100
gen_dev['Woman'] = gen_dev['Woman']/ (a+b+ gen_dev['Woman'])*100
gen_dev.sort_values(by= 'Woman', ascending= False)
# Out:
# Gender                                               Man  \
# Marketing or sales professional                86.527514
# Data scientist or machine learning specialist  90.260509
# Data or business analyst                       90.917134
# Developer, front-end                           91.803897
# Designer                                       91.683300
# Developer, QA or test                          91.846873
# Academic researcher                            91.982556
# Educator                                       92.132179
# Scientist                                      92.320534
# Developer, full-stack                          93.109251
# Engineer, data                                 93.591747
# Developer, mobile                              93.876549
# Developer, back-end                            93.747375
# Product manager                                94.434223
# Database administrator                         94.815853
# Developer, game or graphics                    94.292804
# Developer, desktop or enterprise applications  95.193241
# Senior executive/VP                            95.181818
# Engineering manager                            95.274262
# Developer, embedded applications or devices    95.547860
# Engineer, site reliability                     95.173632
# System administrator                           95.993069
# DevOps specialist                              96.245991
#
# Gender                                         Non-binary, genderqueer, or gender non-conforming  \
# Marketing or sales professional                                                         1.328273
# Data scientist or machine learning specialist                                           0.680876
# Data or business analyst                                                                0.766735
# Developer, front-end                                                                    0.678818
# Designer                                                                                0.931470
# Developer, QA or test                                                                   0.818235
# Academic researcher                                                                     0.872191
# Educator                                                                                0.865460
# Scientist                                                                               1.001669
# Developer, full-stack                                                                   0.681503
# Engineer, data                                                                          0.593936
# Developer, mobile                                                                       0.503129
# Developer, back-end                                                                     0.671874
# Product manager                                                                         0.367985
# Database administrator                                                                  0.740592
# Developer, game or graphics                                                             1.364764
# Developer, desktop or enterprise applications                                           0.602059
# Senior executive/VP                                                                     0.636364
# Engineering manager                                                                     0.632911
# Developer, embedded applications or devices                                             0.667821
# Engineer, site reliability                                                              1.236021
# System administrator                                                                    1.039636
# DevOps specialist                                                                       0.848896
#
# Gender                                             Woman
# Marketing or sales professional                12.144213
# Data scientist or machine learning specialist   9.058615
# Data or business analyst                        8.316131
# Developer, front-end                            7.517285
# Designer                                        7.385230
# Developer, QA or test                           7.334892
# Academic researcher                             7.145253
# Educator                                        7.002360
# Scientist                                       6.677796
# Developer, full-stack                           6.209247
# Engineer, data                                  5.814317
# Developer, mobile                               5.620322
# Developer, back-end                             5.580751
# Product manager                                 5.197792
# Database administrator                          4.443555
# Developer, game or graphics                     4.342432
# Developer, desktop or enterprise applications   4.204700
# Senior executive/VP                             4.181818
# Engineering manager                             4.092827
# Developer, embedded applications or devices     3.784319
# Engineer, site reliability                      3.590347
# System administrator                            2.967295
# DevOps specialist                               2.905112

# %% [markdown]
# #### Which positions have the highest percentage of women?
# * **Marketing or sales professional** with 12.14%
# * Followed by **Data scientist or machine learning specialist** with 9.05

# %% [markdown]
# ## `Job Satisfaction`

# %%
temp= sdf['JobSat'].copy()
display(temp.value_counts(dropna=True))
# Out:
# Very satisfied                        14502
# Slightly satisfied                    13811
# Slightly dissatisfied                  7070
# Neither satisfied nor dissatisfied     5747
# Very dissatisfied                      3705
# Name: JobSat, dtype: int64

# %%
a= sdf['JobSat']
b = sdf['Gender']
temp= pd.concat([a, b], axis=1) 
temp.dropna(inplace=True)
male= temp.value_counts().head()
female= temp.value_counts().iloc[5:10]
third = temp.value_counts().iloc[10:16]

gender= [male, female, third]
# Pie chart
###### Use when trying to COMPARE A CATEGORY or GROUP OF CATEGORIES to the TOTAL  #########
j=1
for i in gender:
    plt.figure(figsize=(18,25))
    plt.subplot(1,3,j)
    labels = i.index 
    sizes = i
    #colors
    colors = ['#24477f','#0892d0','#66b3ff', '#6fd0fc','#80d7ff']
    #explsion
    explode = (0.05,0.05,0.05,0.05,0.05)
    plt.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=180, pctdistance=0.85, explode =explode)
    #draw circle
    centre_circle = plt.Circle((0,0),0.70,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    # Equal aspect ratio ensures that pie is drawn as a circle  
    j=j+1
    plt.show()

# %% [markdown]
# ## `Work Week Hours`

# %%
schema.WorkWeekHrs
# Out:
# 'On average, how many hours per week do you work? Please enter a whole number in the box.'

# %%
plt.figure(figsize=(12, 6))
plt.title(schema.WorkWeekHrs)
plt.xlabel('WorkWeekHrs')
plt.ylabel('Probability Density')
sns.distplot(sdf.WorkWeekHrs , color='blue', rug=True, rug_kws = { 'height': 0.02, 'color': 'xkcd:navy'}, kde_kws={'lw':2, 'color': 'xkcd:navy', 'bw':0.1})
plt.show();
print('Mean Work hour/Week is: ', int(sdf.WorkWeekHrs.mean()),'Hour per Week')
# Out:
# Mean Work hour/Week is:  40 Hour per Week

# %% [markdown]
# ## `Hobbyist` relation with `JobSat`

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39394 entries, 0 to 64152
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   JobSat  39394 non-null  object
#  1   Gender  39394 non-null  object
# dtypes: object(2)
# memory usage: 923.3+ KB

# %%
a= sdf.Hobbyist
a.replace(('Yes', 'No'), (True, False), inplace=True)
a= a.astype(bool)
b = sdf.JobSat
#temp = pd.DataFrame([a,b])
temp= pd.concat([a, b], axis=1) 
temp.dropna(inplace=True)
i=temp.groupby('JobSat').sum().sort_values(by= 'Hobbyist', ascending= False)
display(i)
print()
## Ploting a pie plot

labels = i.index 
sizes = i.Hobbyist
#colors
colors = ['#24477f','#0892d0','#66b3ff', '#6fd0fc','#80d7ff']
#explsion
explode = (0.05,0.05,0.05,0.05,0.05)
plt.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=180, pctdistance=0.85, explode =explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle  
plt.title('Relation of Job Satisfaction with relation to Hobbyist')
plt.show()
# Out:
#                                     Hobbyist
# JobSat
# Very satisfied                         11340
# Slightly satisfied                     10476
# Slightly dissatisfied                   5384
# Neither satisfied nor dissatisfied      4326
# Very dissatisfied                       2817

# %%
sdf
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 0      Computer science, computer engineering, or sof...     True        13.0
# 1      Computer science, computer engineering, or sof...    False        19.0
# 2                                                    NaN     True        15.0
# 3      Computer science, computer engineering, or sof...     True        18.0
# 4      Computer science, computer engineering, or sof...     True        16.0
# ...                                                  ...      ...         ...
# 64456  Computer science, computer engineering, or sof...     True        16.0
# 64457                                                NaN     True         NaN
# 64458                                                NaN     True         NaN
# 64459                                                NaN     True         NaN
# 64460  Computer science, computer engineering, or sof...     True         NaN
#
#        YearsCode  YearsCodePro  \
# 0           36.0          27.0
# 1            7.0           4.0
# 2            4.0           NaN
# 3            7.0           4.0
# 4           15.0           8.0
# ...          ...           ...
# 64456       10.0           NaN
# 64457        NaN           NaN
# 64458        NaN           NaN
# 64459        NaN           NaN
# 64460        NaN           NaN
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64456                                                NaN  Once a decade
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64458                                                NaN            NaN
# 64459                           HTML/CSS;Java;JavaScript    Once a year
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64456                          Call a coworker or friend
# 64457                                                NaN
# 64458                                                NaN
# 64459     Call a coworker or friend;Visit Stack Overflow
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...         50.0
# 1                Developer, full-stack;Developer, mobile          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN         40.0
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 64456                                Senior executive/VP          NaN
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459                                                NaN          NaN
# 64460                                                NaN          NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64456                      Very important
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460                Critically important
#
# [64306 rows x 20 columns]

# %% [markdown]
# ## Asking and Answering Questions
#
# We've already gained several insights about the respondents and the programming community by exploring individual columns of the dataset. Let's ask some specific questions and try to answer them using data frame operations and visualizations.

# %% [markdown]
# #### Q: What are the most popular programming languages in 2020?
#
# To answer, this we can use the `LanguageWorkedWith` column. Similar to `DevType`, respondents were allowed to choose multiple options here.

# %%
sdf.LanguageWorkedWith
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64306, dtype: object

# %%
languages_worked_df = split_multicolumn(sdf.LanguageWorkedWith)

# %%
languages_worked_df
# Out:
#           C#  HTML/CSS  JavaScript  Swift  Objective-C  Python   Ruby    SQL  \
# 0       True      True        True  False        False   False  False  False
# 1      False     False        True   True        False   False  False  False
# 2      False     False       False   True         True    True  False  False
# 3      False     False       False  False        False   False  False  False
# 4      False      True       False  False        False   False   True   True
# ...      ...       ...         ...    ...          ...     ...    ...    ...
# 64456  False     False       False  False        False   False  False  False
# 64457   True      True        True   True         True    True   True   True
# 64458  False     False       False  False        False   False  False  False
# 64459  False      True       False  False        False   False  False  False
# 64460   True      True        True  False        False   False  False   True
#
#         Java    PHP      C  TypeScript  Bash/Shell/PowerShell  Kotlin      R  \
# 0      False  False  False       False                  False   False  False
# 1      False  False  False       False                  False   False  False
# 2      False  False  False       False                  False   False  False
# 3      False  False  False       False                  False   False  False
# 4      False  False  False       False                  False   False  False
# ...      ...    ...    ...         ...                    ...     ...    ...
# 64456  False  False  False       False                  False   False  False
# 64457   True   True   True        True                   True    True   True
# 64458  False  False  False       False                  False   False  False
# 64459  False  False  False       False                  False   False  False
# 64460   True  False  False       False                  False   False  False
#
#          VBA   Perl  Scala    C++     Go  Haskell   Rust   Dart  Julia  \
# 0      False  False  False  False  False    False  False  False  False
# 1      False  False  False  False  False    False  False  False  False
# 2      False  False  False  False  False    False  False  False  False
# 3      False  False  False  False  False    False  False  False  False
# 4      False  False  False  False  False    False  False  False  False
# ...      ...    ...    ...    ...    ...      ...    ...    ...    ...
# 64456  False  False  False  False  False    False  False  False  False
# 64457   True   True   True   True   True     True   True   True   True
# 64458  False  False  False  False  False    False  False  False  False
# 64459  False  False  False  False  False    False  False  False  False
# 64460  False  False  False  False  False    False  False  False  False
#
#        Assembly
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 64456     False
# 64457      True
# 64458     False
# 64459     False
# 64460     False
#
# [64306 rows x 25 columns]

# %% [markdown]
# It appears that a total of 25 languages were included among the options. Let's aggregate these to identify the percentage of respondents who selected each language.

# %%
languages_worked_percentages = languages_worked_df.mean().sort_values(ascending=False) * 100
languages_worked_percentages
# Out:
# JavaScript               59.893323
# HTML/CSS                 55.801947
# SQL                      48.444935
# Python                   39.001026
# Java                     35.618760
# Bash/Shell/PowerShell    29.239884
# C#                       27.803004
# PHP                      23.130035
# TypeScript               22.461357
# C++                      21.114670
# C                        19.236152
# Go                        7.758219
# Kotlin                    6.887382
# Ruby                      6.229590
# Assembly                  5.447392
# VBA                       5.394520
# Swift                     5.226573
# R                         5.064846
# Rust                      4.498803
# Objective-C               3.603085
# Dart                      3.517557
# Scala                     3.150561
# Perl                      2.757130
# Haskell                   1.861413
# Julia                     0.782198
# dtype: float64

# %%
### Creating custom color for this visualization
custom = sns.color_palette(mck_color25)
custom[3] = 'red'
custom[2] = 'green'

### visualization the data 

plt.figure(figsize=(12, 12))
sns.barplot(x=languages_worked_percentages, y=languages_worked_percentages.index, palette= custom)
plt.title("Languages used in the past year");
plt.xlabel('count');

# %% [markdown]
# Perhaps unsurprisingly, Javascript & HTML/CSS comes out at the top as web development is one of today's most sought skills. It also happens to be one of the easiest to get started. SQL is necessary for working with relational databases, so it's no surprise that most programmers work with SQL regularly. Python seems to be the popular choice for other forms of development, beating out Java, which was the industry standard for server & application development for over two decades.
#
# **Way ahead**:
#
# * What are the most common languages used by students? How does the list compare with the most common languages used by professional developers?
# * What are the most common languages among respondents who do not describe themselves as "Developer, front-end"?
# * What are the most common languages among respondents who work in fields related to data science?
# * What are the most common languages used by developers older than 40 years of age?
# * What are the most common languages used by developers in India?

# %% [markdown]
# #### Q: Which languages are the most people interested to learn over the next year?
#
# For this, we can use the `LanguageDesireNextYear` column, with similar processing as the previous one.

# %%
languages_interested_df = split_multicolumn(sdf.LanguageDesireNextYear)
languages_interested_percentages = languages_interested_df.mean().sort_values(ascending=False) * 100
languages_interested_percentages
# Out:
# Python                   41.143906
# JavaScript               40.425466
# HTML/CSS                 32.028116
# SQL                      30.799614
# TypeScript               26.451653
# C#                       21.058688
# Java                     20.464653
# Go                       19.432090
# Bash/Shell/PowerShell    18.057413
# Rust                     16.270643
# C++                      15.014151
# Kotlin                   14.760676
# PHP                      10.947657
# C                         9.359935
# Swift                     8.692812
# Dart                      7.308805
# R                         6.571704
# Ruby                      6.425528
# Scala                     5.326097
# Haskell                   4.593662
# Assembly                  3.766367
# Julia                     2.540976
# Objective-C               2.338818
# Perl                      1.761888
# VBA                       1.611047
# dtype: float64

# %%
### Creating custom color for this visualization
custom = sns.color_palette(mck_color25)
custom[0] = 'red'
custom[3] = 'green'

### Visualization
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_interested_percentages, y=languages_interested_percentages.index, palette = custom)
plt.title("Languages people are intersted in learning over the next year");
plt.xlabel('count');

# %% [markdown]
# Once again, it's not surprising that Python is the language most people are interested in learning - since it is an easy-to-learn general-purpose programming language well suited for a variety of domains: application development, numerical computing, data analysis, machine learning, big data, cloud automation, web scraping, scripting, etc. We're using Python for this very analysis, so we're in good company!
#
# **Way ahead**: Repeat the exercises from the previous question, replacing "most common languages" with "languages people are interested in learning/using."

# %% [markdown]
# #### Q:  Which are the most loved languages, i.e., a high percentage of people who have used the language want to continue learning & using it over the next year?
#
# While this question may seem tricky at first, it's straightforward to solve using Pandas array operations. Here's what we can do:
#
# - Create a new data frame `languages_loved_df` that contains a `True` value for a language only if the corresponding values in `languages_worked_df` and `languages_interested_df` are both `True`
# - Take the column-wise sum of `languages_loved_df` and divide it by the column-wise sum of `languages_worked_df` to get the percentage of respondents who "love" the language
# - Sort the results in decreasing order and plot a horizontal bar graph

# %%
languages_loved_df = languages_worked_df & languages_interested_df

# %%
languages_loved_percentages = (languages_loved_df.sum() * 100/ languages_worked_df.sum()).sort_values(ascending=False)

# %%
### Creating custom color for this visualization
custom = sns.color_palette(mck_color25)
custom[2] = 'red'
custom[10] = 'green'
### Visualization

plt.figure(figsize=(12, 12))
sns.barplot(x=languages_loved_percentages, y=languages_loved_percentages.index, palette= custom)
plt.title("Most loved languages");
plt.xlabel('count');

# %% [markdown]
# [Rust](https://www.rust-lang.org) has been StackOverflow's most-loved language for [four years in a row](https://stackoverflow.blog/2020/01/20/what-is-rust-and-why-is-it-so-popular/). The second most-loved language is TypeScript, a popular alternative to JavaScript for web development.
#
# Python features at number 3, despite already being one of the most widely-used languages in the world. Python has a solid foundation, is easy to learn & use, has a large ecosystem of domain-specific libraries, and a massive worldwide community.
#
# **Way ahead:** What are the most dreaded languages, i.e., languages which people have used in the past year but do not want to learn/use over the next year. Hint: `~languages_interested_df`.

# %% [markdown]
# #### Q: In which countries do developers work the highest number of hours per week? Consider countries with more than 250 responses only.
#
# To answer this question, we'll need to use the `groupby` data frame method to aggregate the rows for each country. We'll also need to filter the results to only include the countries with more than 250 respondents.

# %%
countries_df = sdf.groupby('Country')[['WorkWeekHrs']].mean().sort_values('WorkWeekHrs', ascending=False)

# %%
high_response_countries_df = countries_df.loc[sdf.Country.value_counts() > 250].head(15)

# %%
high_response_countries_df
# Out:
#                WorkWeekHrs
# Country
# Iran             44.337748
# Israel           43.915094
# China            42.150000
# United States    41.802982
# Greece           41.402724
# Viet Nam         41.391667
# South Africa     41.023460
# Turkey           40.982143
# Sri Lanka        40.612245
# New Zealand      40.457551
# Belgium          40.444444
# Canada           40.208837
# Hungary          40.194340
# Bangladesh       40.097458
# India            40.090603

# %% [markdown]
# The Asian countries like Iran, China, and Israel have the highest working hours, followed by the United States. However, there isn't too much variation overall, and the average working hours seem to be around 40 hours per week.
#
# **Way ahead:**
#
# * How do the average work hours compare across continents? You may find this list of [countries in each continent](https://hub.jovian.ml/wp-content/uploads/2020/09/countries.csv) useful.
# * Which role has the highest average number of hours worked per week? Which one has the lowest?
# * How do the hours worked compare between freelancers and developers working full-time?

# %% [markdown]
# #### Q: How important is it to start young to build a career in programming?
#
# Let's create a scatter plot of `Age` vs. `YearsCodePro` (i.e., years of coding experience) to answer this question.

# %%
schema.YearsCodePro
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
sns.scatterplot(x='Age', y='YearsCodePro', hue='Hobbyist', data=sdf, palette=mck_color2)
plt.xlabel("Age")
plt.ylabel("Years of professional coding experience");

# %% [markdown]
# You can see points all over the graph, which indicates that you can **start programming professionally at any age**. Many people who have been coding for several decades professionally also seem to enjoy it as a hobby.
#
# We can also view the distribution of the `Age1stCode` column to see when the respondents tried programming for the first time.

# %%
plt.title(schema.Age1stCode)
sns.histplot(x=sdf.Age1stCode, bins=30, kde=True);

# %% [markdown]
# As you might expect, most people seem to have had some exposure to programming before the age of 40. However, but there are people of all ages and walks of life learning to code.

# %% [markdown]
# #### Q: What are the most common languages used by developers older than 40 years of age?

# %%
a=sdf[sdf["Age"]>40]
b = split_multicolumn(a.LanguageWorkedWith)

languages_worked_percentages = b.mean().sort_values(ascending=False) * 100

### Creating custom color for this visualization
custom = sns.color_palette(mck_color25)
custom[4] = 'red'
custom[1] = 'green'

### visualization the data 

plt.figure(figsize=(12, 12))
sns.barplot(x=languages_worked_percentages, y=languages_worked_percentages.index, palette= custom)
plt.title("Languages used by users above 40 Years");
plt.xlabel('Percentage');

# %% [markdown]
# #### Q: Check for popularly used language by users with 20+ years of experience

# %%
a = sdf[sdf['YearsCodePro']>20]
b= split_multicolumn(a.LanguageWorkedWith)

languages_worked_percentages = b.mean().sort_values(ascending=False) * 100

### Creating custom color for this visualization
custom = sns.color_palette(mck_color25)
custom[5] = 'red'
custom[0] = 'green'

### visualization the data 
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_worked_percentages, y=languages_worked_percentages.index, palette= custom)
plt.title("Languages used by programmers with 20+ years of experience");
plt.xlabel('Percentage');

# %%
### For gender 
i=a['Gender']
i.dropna(inplace=True)
## Ploting a pie plot

labels = i.unique()
sizes = i.value_counts()

#colors
colors = ['#24477f','#0892d0','#66b3ff', '#6fd0fc','#80d7ff']
#explsion
explode = (0.05,0.05,0.05)
plt.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=180, pctdistance=0.85, explode =explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle  
plt.title('Gender-wise work force distribution of people with 20+ yrs of experience')
plt.show()

# %% [markdown]
# #### Q: What are the most common languages used by developers in India?

# %%
a=sdf[sdf['Country']=='India']
b = split_multicolumn(a.LanguageWorkedWith)

languages_worked_percentages = b.mean().sort_values(ascending=False) * 100

### Creating custom color for this visualization
custom = sns.color_palette(mck_color25)
custom[4] = 'red'
custom[2] = 'green'

### visualization the data 

plt.figure(figsize=(12, 12))
sns.barplot(x=languages_worked_percentages, y=languages_worked_percentages.index, palette= custom)
plt.title("Most common languages used by developers in India");
plt.xlabel('Percentage');

# %% [markdown]
# # Q: Language usage with respect to devtype

# %% [markdown]
# # Inferences and Conclusions
#
# We've drawn many inferences from the survey. Here's a summary of a few of them:
#
# - Based on the survey respondents' demographics, we can infer that the survey is somewhat representative of the overall programming community. However, it has fewer responses from programmers in non-English-speaking countries and women & non-binary genders.
#
# - The programming community is not as diverse as it can be. Although things are improving, we should make more efforts to support & encourage underrepresented communities, whether in terms of age, country, race, gender, or otherwise.
#
#
# - Although most programmers hold a college degree, a reasonably large percentage did not have computer science as their college major. Hence, a computer science degree isn't compulsory for learning to code or building a career in programming.
#
# - A significant percentage of programmers either work part-time or as freelancers, which can be a great way to break into the field, especially when you're just getting started.
#
# - Javascript & HTML/CSS are the most used programming languages in 2020, closely followed by SQL & Python.
#
# - Python is the language most people are interested in learning - since it is an easy-to-learn general-purpose programming language well suited for various domains.
#
# - Rust and TypeScript are the most "loved" languages in 2020, both of which have small but fast-growing communities. Python is a close third, despite already being a widely used language.
#
# - Programmers worldwide seem to be working for around 40 hours a week on average, with slight variations by country.
#
# - You can learn and start programming professionally at any age. You're likely to have a long and fulfilling career if you also enjoy programming as a hobby.
#
# - **SQL and Python** are 2nd and 5th most popular language in India which is used for Data Science. Where as **R is 17th** most popular language in India.
# ### Way ahead
# **Will compare these finding with kaggle survey finding, as it more targeted towards data science community**

# %% [markdown]
# ## If u like this Notebook Please upvote this notebook !!!
# **And comment any suggestion in comment, `Thank You!!!`**
